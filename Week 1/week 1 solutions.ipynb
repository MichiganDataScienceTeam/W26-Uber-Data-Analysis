# %% [markdown]
# Import the libraries necessary to start your journey!

# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# 1. Read in the dataset. Run .describe() and .info() to return relevant data. Play around with the parameters!

# %%
df = pd.read_csv('wine.csv')
df.info()
# verbose=boolean, memory_usage=boolean
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# 2. Kenny only wants to know about the first 15 wines in the sample. Help him out!

# %%
df.head(15)

# Depending on their environment, their output may be seperated into different 'pages'.
# Also reminder that the first row begins at 0.
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# 11            7.5             0.500         0.36             6.1      0.071
# 12            5.6             0.615         0.00             1.6      0.089
# 13            7.8             0.610         0.29             1.6      0.114
# 14            8.9             0.620         0.18             3.8      0.176
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 3                  17.0                  60.0   0.9980  3.16       0.58
# 4                  11.0                  34.0   0.9978  3.51       0.56
# 5                  13.0                  40.0   0.9978  3.51       0.56
# 6                  15.0                  59.0   0.9964  3.30       0.46
# 7                  15.0                  21.0   0.9946  3.39       0.47
# 8                   9.0                  18.0   0.9968  3.36       0.57
# 9                  17.0                 102.0   0.9978  3.35       0.80
# 10                 15.0                  65.0   0.9959  3.28       0.54
# 11                 17.0                 102.0   0.9978  3.35       0.80
# 12                 16.0                  59.0   0.9943  3.58       0.52
# 13                  9.0                  29.0   0.9974  3.26       1.56
# 14                 52.0                 145.0   0.9986  3.16       0.88
#
#     alcohol  quality
# 0       9.4        5
# 1       9.8        5
# 2       9.8        5
# 3       9.8        6
# 4       9.4        5
# 5       9.4        5
# 6       9.4        5
# 7      10.0        7
# 8       9.5        7
# 9      10.5        5
# 10      9.2        5
# 11     10.5        5
# 12      9.9        5
# 13      9.1        5
# 14      9.2        5

# %% [markdown]
# 3. Kenny doesn't want super specific values for the chlorides. In the 'chlorides' column, round all decimals to the nearest tenth.

# %%
df['chlorides'].round(2)

# They can also play around with the other functions.

# For example, using .tail() to see the last few rows of the dataframe.
# df['chlorides'].tail(10)

# Or using .sample() to see a random sample of rows.
# df['chlorides'].sample(10)

# Or just getting specific statistical data by column
# df['chlorides'].mean()
# Out:
# (1599, 12)

# %% [markdown]
# 4. Kenny's clients are interested in specific pH balances, so he needs to look at the stats of some wines. Return the mean pH of last 30 wine samples.

# %%
df['pH'].tail(30).mean()

# Logic: First extract only the last 30 tails. Then calculate the mean of that selection.
# Doing .mean() first does not make sense as you cannot get the tail of a mean.
# Out:
# 3.422333333333333

# %% [markdown]
# 5. Kenny thinks he is looking at too many wine samples. Return the data for the 1st, 217th, 400th, and 496th row. # use .iloc()/.loc()

# %%
# Pass a list of the row indices inside iloc
df.iloc[[1, 217, 400, 496]]

# They must pass an array-list of indices to represent the rows they want to extract, with 0 as the starting index.

# They can also use those extracted runs to further run things like .describe(), so that the statistical analysis is more specific to those rows.
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count       3.000000          3.000000     3.000000        3.000000
# mean        6.866667          0.473333     0.203333        1.700000
# std         1.101514          0.202567     0.187705        0.264575
# min         5.600000          0.310000     0.000000        1.400000
# 25%         6.500000          0.360000     0.120000        1.600000
# 50%         7.400000          0.410000     0.240000        1.800000
# 75%         7.500000          0.555000     0.305000        1.850000
# max         7.600000          0.700000     0.370000        1.900000
#
#        chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# count   3.000000             3.000000              3.000000  3.000000
# mean    0.076667             9.000000             47.000000  0.996467
# std     0.003055             4.358899             43.965896  0.001222
# min     0.074000             4.000000             11.000000  0.995400
# 25%     0.075000             7.500000             22.500000  0.995800
# 50%     0.076000            11.000000             34.000000  0.996200
# 75%     0.078000            11.500000             65.000000  0.997000
# max     0.080000            12.000000             96.000000  0.997800
#
#              pH  sulphates   alcohol  quality
# count  3.000000   3.000000  3.000000      3.0
# mean   3.370000   0.576667  9.366667      5.0
# std    0.122882   0.015275  0.152753      0.0
# min    3.280000   0.560000  9.200000      5.0
# 25%    3.300000   0.570000  9.300000      5.0
# 50%    3.320000   0.580000  9.400000      5.0
# 75%    3.415000   0.585000  9.450000      5.0
# max    3.510000   0.590000  9.500000      5.0

# %% [markdown]
# 6. Kenny's client wants a wine that has a fixed acidity > 6.2, alcohol < 9.5, quality > 5, AND volatile acidity < 0.6. Create a new column, name it "satisfactory", and return either "yes" or "no" depending on whether the conditions are satisfied.

# %%
df['satisfactory'] = False

# Iniitliaze all these values to False. The approach is to default it to false, then modify those which meet the conditions.
df.head()
# To check the df was properly updated.

df.loc[
    (df['fixed acidity'] > 6.2) & 
    (df['alcohol'] < 9.5) & 
    (df['quality'] > 5) & 
    (df['volatile acidity'] < 0.6), 
    'satisfactory'] = True
# The brackets should have conditio,.ns separated by &. 

df.head(50)
# To check if the satisfactory column was properly updated.
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# 11            7.5             0.500         0.36             6.1      0.071
# 12            5.6             0.615         0.00             1.6      0.089
# 13            7.8             0.610         0.29             1.6      0.114
# 14            8.9             0.620         0.18             3.8      0.176
# 15            8.9             0.620         0.19             3.9      0.170
# 16            8.5             0.280         0.56             1.8      0.092
# 17            8.1             0.560         0.28             1.7      0.368
# 18            7.4             0.590         0.08             4.4      0.086
# 19            7.9             0.320         0.51             1.8      0.341
# 20            8.9             0.220         0.48             1.8      0.077
# 21            7.6             0.390         0.31             2.3      0.082
# 36                  3.0                  15.0   0.9975  3.42       0.60
# 37                 13.0                  30.0   0.9968  3.23       0.73
# 38                  7.0                  19.0   0.9940  3.50       0.48
# 39                 12.0                  87.0   0.9978  3.33       0.83
# 40                 12.0                  87.0   0.9978  3.33       0.83
# 41                 17.0                  46.0   0.9976  3.26       0.51
# 42                  8.0                  14.0   0.9968  3.21       0.90
# 43                  9.0                  23.0   0.9968  3.30       1.20
# 44                  5.0                  11.0   0.9962  3.48       0.52
# 45                  8.0                  65.0   0.9934  3.90       0.56
# 46                 22.0                 114.0   0.9970  3.25       0.73
# 47                 12.0                  37.0   0.9969  3.25       0.58
# 48                  5.0                  12.0   0.9958  3.34       0.56
# 49                 12.0                  96.0   0.9954  3.32       0.58
#
#     alcohol  quality  satisfactory
# 0       9.4        5         False
# 1       9.8        5         False
# 2       9.8        5         False
# 3       9.8        6         False
# 4       9.4        5         False
# 5       9.4        5         False
# 6       9.4        5         False
# 7      10.0        7         False
# 8       9.5        7         False
# 9      10.5        5         False
# 10      9.2        5         False
# 11     10.5        5         False
# 12      9.9        5         False
# 13      9.1        5         False
# 14      9.2        5         False
# 15      9.2        5         False
# 16     10.5        7         False
# 17      9.3        5         False
# 18      9.0        4         False
# 19      9.2        6          True
# 20      9.4        6          True
# 21      9.7        5         False
# 22      9.5        5         False
# 23      9.4        5         False
# 24      9.7        6         False
# 25      9.3        5         False
# 26      9.5        5         False
# 27      9.5        5         False
# 28      9.4        5         False
# 29      9.8        6         False
# 30     10.1        5         False
# 31     10.6        6         False
# 32      9.8        5         False
# 33      9.4        6         False
# 34      9.2        5         False
# 35      9.6        6         False
# 36     10.8        6         False
# 37      9.7        7         False
# 38      9.8        4         False
# 39     10.5        5         False
# 40     10.5        5         False
# 41      9.3        4         False
# 42     10.5        6         False
# 43     10.3        5         False
# 44      9.5        5         False
# 45     13.1        4         False
# 46      9.2        5         False
# 47      9.5        5         False
# 48      9.2        5         False
# 49      9.2        5         False

# %% [markdown]
# 7. Kenny does not think the column labelled alcohol is a good label name, as all wine contains alcohol, and it is a numerical column. Rename this column to alc percentage, and be sure to modify the original dataframe. HINT (remember inplace)

# %%
df.rename({'alcohol':'alc percentage'}, axis = 1, inplace = T)

# %% [markdown]
# 8. To prioritize the best products, sort the 'quality' column in desecending order.

# %%
df.sort_values(by = 'quality',ascending = False)

# %% [markdown]
# 9. Kenny only cares about fixed acidity, density, and chlorides. Return just these three columns

# %%
df[['fixed acidity', 'density', 'chlorides']]

# %% [markdown]
# 10. Kenny's clients only want wine that has a density higher than 0.9965, and they want to look at all the available wines that meet this condition, but only care about the density, total sulfur dioxide, and quality. Return this in one statemnt.

# %%
df[df['density'] < 0.9965]['density', 'total sulfur dioxide', 'quality']

# %% [markdown]
# 11. Using the 'fixed acidity' and 'voltaile acidity' columns, calculate a ratio per row (rounded to the nearest hundredth) and put it in a new column called 'acidity_ratio'.

# %%
df['acidity_ratio'] = df['fixed_acidity']/df['volatile acidity']
