# %% [markdown]
# As always, import relevant libraries, which we provided.
#
# ---

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import Holt
from statsmodels.tsa.arima.model import ARIMA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Read in your dataset and verify it is working.

# %% [markdown]
# 1. Make sure all your START_DATE are datetime objects.
#
# Group them by day.
#
# Fix the indexing by formatting it in datetime index format.

# %%
# Hint: Use .groupby!

#Hint with indexing: Reuse the pd.to_datetime function!

# %% [markdown]
# 2. (VERY IMPORTANT!) Fill in missing days with 0. If we don't do it, our graph will not know how to address the many days without data.
#
# Also, create two variables: train and test, which each representing a split dataset.

# %%
# Fill missing days with 0 (CRITICAL for statsmodels)
# Use .asfreq pandas function

# 2. Split data: Hide the last 30 days

# %% [markdown]
# 3. Forecast the expected number of rides throughout the year by day, then graph it!

# %%
# 3. Use the Forecasting Module!


# 4. Plot it

# %% [markdown]
# 4. Instead of forecasting the # of rides, we want to now see how many miles we will reach by the end of the year.
#
# Using Holt's model, split the data at November 1st (train is anything before, test is anything after).
#
# Forecast the cumulative miles for 2016.

# %%
# Since we already have df loaded, let's look at Cumulative Miles


# 2. Split Data (Hide November and December)


# 3. Use the Forecasting Module! (Swapping SES for Holt)


# 4. Plot it

# %% [markdown]
# 5. Finally, let's do something similar as we did in SimpleForecasting, except this time we're using ARIMA for weekly mileage.
#
# Your train set: all data before the last 8 weeks
# Your test set: ONLY the last 8 weeks
#
# Let your order be (1, 1, 1).

# %%
# 2. Split Data

# 3. Use the Forecasting Module!
# order=(1,1,1) tells ARIMA to use 1 past step, 1 level of smoothing, and 1 past error.


# 4. Plot it
