# %% [markdown]
# <a href="https://colab.research.google.com/github/MichiganDataScienceTeam/W26-Uber-Data-Analysis/blob/main/Week_2_solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Import the relevant libraries.

# %%
import requests
import re
import pandas as pd
import numpy as np
import os
import json
from datetime import datetime
from urllib.parse import quote

# %% [markdown]
# 2. Load the "corrupted" dataset. Make sure to run methods like .head() and .info() to make sure it was loaded properly!

# %%
df = pd.read_csv(
    "UberDataset [CORRUPTED].csv")

# %% [markdown]
# 3. Iterate through all dataframe columns to check for NaN (empty) cells. If you find one, override the cell with '**NO_DATA**'.

# %%
for col in df.columns:
    df[col] = df[col].fillna("NO_DATA")

# %% [markdown]
# 4. Focus at the START and STOP columns. Scroll around a bit and find the typos. Make a custom pattern that can be used for both typo formats. **OVERRIDE** the previous cell.
#
# The correct words should be: Rawalpindi and Karachi.
#
# Hint: use r'STRING' (raw) for your pattern, and use .findall(pattern, string).

# %%
pattern = r'([A-Z][a-z]*)\?([a-z]*)'
for i in df.index:
  startVal = df.at[i, 'START']
  stopVal = df.at[i, 'STOP']
  if '?' in startVal:
    grouping = re.findall(pattern, startVal)[0]
    firstPart = grouping[0]
    secondPart = grouping[1]
    fixedWord = f'{firstPart}a{secondPart}'
    df.at[i, 'START'] = fixedWord


  if '?' in stopVal:
    grouping = re.findall(pattern, stopVal)[0]
    firstPart = grouping[0]
    secondPart = grouping[1]
    fixedWord = f'{firstPart}a{secondPart}'
    df.at[i, 'STOP'] = fixedWord

df.head(500)
# Out:
#            START_DATE          END_DATE  CATEGORY        START     STOP  \
# 0    11-05-2016 19:20  11-05-2016 19:28  Business        Agnew    Agnew
# 1    11-04-2016 22:12  11-04-2016 22:25  Business         Cory    Agnew
# 2    11-05-2016 17:29  11-05-2016 17:40  Business  Renaissance    Agnew
# 3    11-06-2016 16:05  11-06-2016 16:22  Business  Renaissance    Agnew
# 4     3/17/2016 17:20   3/17/2016 18:02  Business      Midtown    Alief
# ..                ...               ...       ...          ...      ...
# 495  12/28/2016 18:33  12/28/2016 18:56  Business      Karachi  Karachi
# 496  12/28/2016 22:44  12/28/2016 23:18  Business      Karachi  Karachi
# 497   12/29/2016 0:49   12/29/2016 1:06  Business      Karachi  Karachi
# 498  12/29/2016 12:25  12/29/2016 12:33  Business      Karachi  Karachi
# 499  12/29/2016 13:17  12/29/2016 13:24  Business      Karachi  Karachi
#
#      MILES          PURPOSE
# 0      2.2          NO_DATA
# 1      3.9          NO_DATA
# 2      2.8          NO_DATA
# 3      2.8          Meeting
# 4     15.5   Meal/Entertain
# ..     ...              ...
# 495    3.8  Errand/Supplies
# 496    5.1  Errand/Supplies
# 497    3.8  Errand/Supplies
# 498    1.4  Errand/Supplies
# 499    1.1  Errand/Supplies
#
# [500 rows x 7 columns]

# %% [markdown]
# 5. Override all 'Unknown Location' values to 'NO_DATA'

# %%
for i in df.index:
  startVal = df.at[i, 'START']
  stopVal = df.at[i, 'STOP']
  if 'Unknown' in startVal:
    df.at[i, 'START'] = 'NO_DATA'
  if 'Unknown' in stopVal:
    df.at[i, 'STOP'] = 'NO_DATA'
df.tail(500)
# Out:
#             START_DATE          END_DATE  CATEGORY        START  \
# 654   07-03-2016 00:28  07-03-2016 00:38  Business         Cary
# 655   07-06-2016 20:04  07-06-2016 20:14  Business         Cary
# 656   07-07-2016 08:22  07-07-2016 08:50  Business         Cary
# 657    7/13/2016 12:39   7/13/2016 13:20  Personal         Cary
# 658    7/14/2016 15:51   7/14/2016 15:59  Personal         Cary
# ...                ...               ...       ...          ...
# 1149  11-01-2016 19:14  11-01-2016 19:20  Business  Whitebridge
# 1150  11-01-2016 19:59  11-01-2016 20:12  Business  Whitebridge
# 1151  11-01-2016 20:41  11-01-2016 20:55  Business  Whitebridge
# 1152  02-02-2016 13:04  02-02-2016 13:23  Business  Whitebridge
# 1153  10/28/2016 15:53  10/28/2016 17:59  Business         Cary
#
#                     STOP  MILES          PURPOSE
# 654          Morrisville    3.1  Errand/Supplies
# 655          Morrisville    3.3   Meal/Entertain
# 656          Morrisville    7.9   Temporary Site
# 657          Morrisville   23.5          NO_DATA
# 658          Morrisville    3.3          NO_DATA
# ...                  ...    ...              ...
# 1149         Whitebridge    1.0          NO_DATA
# 1150         Whitebridge    4.1          NO_DATA
# 1151         Whitebridge    4.2   Meal/Entertain
# 1152  Williamsburg Manor    8.3          Meeting
# 1153       Winston Salem  107.0          Meeting
#
# [500 rows x 7 columns]

# %% [markdown]
# 6. Convert all the START_DATE and END_DATE values to datetime objects.

# %%
df['START_DATE'] = pd.to_datetime(df['START_DATE'], errors='coerce', format='mixed')
df['END_DATE'] = pd.to_datetime(df['END_DATE'], errors='coerce', format='mixed')

# %% [markdown]
# 7. Create a function that validate that timings for the trip makes sense (start date should be less than end date), and if not, sets both START_DATE and END_DATE to NaT

# %%
def invalid_trip_time(df: pd.DataFrame) -> pd.DataFrame:
  invalid = df["START_DATE"] >= df["END_DATE"]

  df.loc[invalid, "START_DATE"] = pd.NaT
  df.loc[invalid, "END_DATE"] = pd.NaT

  return df

# %% [markdown]
# 8. Extract these specific time features: hour, day of the week, if it is rush hour (let rush hour be between 7-9 am and 4-6 pm), and if it is the weekend (based on START_DATE column)

# %%
df["hour"] = df["START_DATE"].dt.hour
df["day_of_week"] = df["START_DATE"].dt.dayofweek
df["is_weekend"] = df["day_of_week"] > 5
df["is_rush_hour"] = ((df["hour"].between(7,9)) |  (df["hour"].between(16,18)))

# %% [markdown]
# # New Section

# %% [markdown]
# 9. Connect to our **GitHub**. The API data is divided up into hourly segments. Using both the **START** location and the **START_DATE**, as well as the datetime attributes, make a web request for each of your rows.
#
# Hint：Find & get the corresponding index in the hourly list, then use that to get the other attributes.
#
# PLEASE CACHE YOUR DATA TO AVOID BURNING THE SERVER.

# %%
# 1. Create a local directory for the cache
cache_dir = 'cached'
if not os.path.exists(cache_dir):
    os.makedirs(cache_dir)

for idx, i in enumerate(df['START']):
    # The local filename where we store the JSON
    cache_file = os.path.join(cache_dir, f"{i}.json")

    # 2. CHECK CACHE: Only make a request if the file isn't local
    if os.path.exists(cache_file):
        with open(cache_file, 'r') as f:
            firstRequest = json.load(f)['hourly']
    else:
        url = f'https://23likenny.github.io/MDSTUber/Week2/{i}.json'
        holder = requests.get(url)

        if holder.status_code == 200:
            full_json = holder.json()
            # SAVE to cache for next time
            with open(cache_file, 'w') as f:
                json.dump(full_json, f)
            firstRequest = full_json['hourly']
        else:
            print(f"Skipping Index {idx}: {i} not found at URL.")
            continue

    x = firstRequest['time']
    currentTime = df.at[idx, 'START_DATE']
    target_str = currentTime.strftime('%Y-%m-%dT%H:00')
    find_idx = x.index(target_str)

    # Pulling your variables
    temperature = firstRequest['apparent_temperature'][find_idx]
    is_day = firstRequest['is_day'][find_idx]
    rain = firstRequest['rain'][find_idx]
    snowfall = firstRequest['snowfall'][find_idx]
    showers = firstRequest['showers'][find_idx]
    weather_code = firstRequest['weather_code'][find_idx]
    wind_speed_10m = firstRequest['wind_speed_10m'][find_idx]
    wind_gusts_10m = firstRequest['wind_gusts_10m'][find_idx]
    print(f'Current Index: {idx}. The temperature is {temperature}')


    # Writing to DataFrame
    df.at[idx, 'TEMPERATURE'] = temperature
    df.at[idx, 'IS_DAY'] = is_day
    df.at[idx, 'RAIN'] = rain
    df.at[idx, 'SNOWFALL'] = snowfall
    df.at[idx, 'SHOWERS'] = showers
    df.at[idx, 'WEATHER_CODE'] = weather_code
    df.at[idx, 'WIND_SPEED_10M'] = wind_speed_10m
    df.at[idx, 'WIND_GUSTS_10M'] = wind_gusts_10m
# Out:
# Current Index: 0. The temperature is 49.3
# Current Index: 1. The temperature is 41.6
# Current Index: 2. The temperature is 52.5
# Current Index: 3. The temperature is 43.9
# Current Index: 4. The temperature is 50.9
# Current Index: 5. The temperature is 75.6
# Current Index: 6. The temperature is 91.5
# Current Index: 7. The temperature is 73.5
# Current Index: 8. The temperature is 35.3
# Current Index: 9. The temperature is 44.0
# Current Index: 10. The temperature is 30.9
# Current Index: 11. The temperature is 55.2
# Current Index: 12. The temperature is 76.6
# Current Index: 13. The temperature is 96.2
# Current Index: 14. The temperature is 91.8
# Current Index: 15. The temperature is 73.5
# Current Index: 16. The temperature is 60.0
# Current Index: 17. The temperature is 44.3
# Current Index: 18. The temperature is 43.7
# Current Index: 19. The temperature is 45.1
# Current Index: 20. The temperature is 28.8
# Current Index: 21. The temperature is 51.0
# Current Index: 22. The temperature is 52.4
# Current Index: 23. The temperature is 96.3
# Current Index: 24. The temperature is 83.7
# Current Index: 25. The temperature is 54.3
# Current Index: 26. The temperature is 60.1
# Current Index: 27. The temperature is 75.8
# Current Index: 28. The temperature is 63.8
# Current Index: 29. The temperature is 74.2
# Current Index: 30. The temperature is 75.2
# Current Index: 31. The temperature is 81.3
# Current Index: 32. The temperature is 69.9
# Current Index: 33. The temperature is 68.7
# Current Index: 34. The temperature is 72.7
# Current Index: 35. The temperature is 83.3
# Current Index: 36. The temperature is 98.7
# Current Index: 37. The temperature is 68.2
# Current Index: 38. The temperature is 53.2
# Current Index: 39. The temperature is 44.4
# Current Index: 40. The temperature is 60.7
# Current Index: 41. The temperature is 58.3
# Current Index: 42. The temperature is 72.3
# Current Index: 43. The temperature is 74.2
# Current Index: 44. The temperature is 71.2
# Current Index: 45. The temperature is 58.4
# Current Index: 46. The temperature is 72.2
# Current Index: 47. The temperature is 71.3
# Current Index: 48. The temperature is 62.7
# Current Index: 49. The temperature is 76.0
# Current Index: 50. The temperature is 68.0
# Current Index: 51. The temperature is 63.4
# Current Index: 52. The temperature is 69.5
# Current Index: 53. The temperature is 52.1
# Current Index: 54. The temperature is 68.6
# Current Index: 55. The temperature is 82.3
# Current Index: 56. The temperature is 72.4
# Current Index: 57. The temperature is 29.6
# Current Index: 58. The temperature is 46.9
# Current Index: 59. The temperature is 68.5
# Current Index: 60. The temperature is 73.5
# Current Index: 61. The temperature is 73.5
# Current Index: 62. The temperature is 58.6
# Current Index: 63. The temperature is 65.0
# Current Index: 64. The temperature is 33.9
# Current Index: 65. The temperature is 37.4
# Current Index: 66. The temperature is 51.5
# Current Index: 67. The temperature is 51.0
# Current Index: 68. The temperature is 30.2
# Current Index: 69. The temperature is 39.4
# Current Index: 70. The temperature is 30.0
# Current Index: 71. The temperature is 58.6
# Current Index: 72. The temperature is 75.4
# Current Index: 73. The temperature is 95.6
# Current Index: 74. The temperature is 92.4
# Current Index: 75. The temperature is 89.8
# Current Index: 76. The temperature is 70.9
# Current Index: 77. The temperature is 34.9
# Current Index: 78. The temperature is 46.5
# Current Index: 79. The temperature is 30.3
# Current Index: 80. The temperature is 52.5
# Current Index: 81. The temperature is 78.9
# Current Index: 82. The temperature is 48.2
# Current Index: 83. The temperature is 24.4
# Current Index: 84. The temperature is 33.7
# Current Index: 85. The temperature is 33.7
# Current Index: 86. The temperature is 33.4
# Current Index: 87. The temperature is 51.2
# Current Index: 88. The temperature is 51.2
# Current Index: 89. The temperature is 34.5
# Current Index: 90. The temperature is 32.8
# Current Index: 91. The temperature is 36.2
# Current Index: 92. The temperature is 54.3
# Current Index: 93. The temperature is 52.0
# Current Index: 94. The temperature is 46.3
# Current Index: 95. The temperature is 50.1
# Current Index: 96. The temperature is 49.6
# Current Index: 97. The temperature is 44.0
# Current Index: 98. The temperature is 48.3
# Current Index: 99. The temperature is 48.3
# Current Index: 100. The temperature is 32.1
# Current Index: 101. The temperature is 33.8
# Current Index: 102. The temperature is 38.6
# Current Index: 103. The temperature is 38.0
# Current Index: 104. The temperature is 39.4
# Current Index: 105. The temperature is 41.7
# Current Index: 106. The temperature is 45.6
# Current Index: 107. The temperature is 45.6
# Current Index: 108. The temperature is 45.6
# Current Index: 109. The temperature is 48.8
# Current Index: 110. The temperature is 47.6
# Current Index: 111. The temperature is 47.6
# Current Index: 112. The temperature is 40.9
# Current Index: 113. The temperature is 45.7
# Current Index: 114. The temperature is 38.9
# Current Index: 115. The temperature is 51.6
# Current Index: 116. The temperature is 50.2
# Current Index: 117. The temperature is 47.6
# Current Index: 118. The temperature is 47.0
# Current Index: 119. The temperature is 49.2
# Current Index: 120. The temperature is 49.2
# Current Index: 121. The temperature is 44.0
# Current Index: 122. The temperature is 41.2
# Current Index: 123. The temperature is 41.9
# Current Index: 124. The temperature is 41.9
# Current Index: 125. The temperature is 35.0
# Current Index: 126. The temperature is 32.3
# Current Index: 127. The temperature is 24.6
# Current Index: 128. The temperature is 22.7
# Current Index: 129. The temperature is 33.7
# Current Index: 130. The temperature is 51.0
# Current Index: 131. The temperature is 46.0
# Current Index: 132. The temperature is 45.6
# Current Index: 133. The temperature is 45.1
# Current Index: 134. The temperature is 44.4
# Current Index: 135. The temperature is 59.6
# Current Index: 136. The temperature is 23.6
# Current Index: 137. The temperature is 30.4
# Current Index: 138. The temperature is 37.9
# Current Index: 139. The temperature is 32.0
# Current Index: 140. The temperature is 26.5
# Current Index: 141. The temperature is 29.1
# Current Index: 142. The temperature is 43.0
# Current Index: 143. The temperature is 38.4
# Current Index: 144. The temperature is 33.9
# Current Index: 145. The temperature is 29.4
# Current Index: 146. The temperature is 55.7
# Current Index: 147. The temperature is 46.9
# Current Index: 148. The temperature is 53.7
# Current Index: 149. The temperature is 59.2
# Current Index: 150. The temperature is 50.5
# Current Index: 151. The temperature is 49.9
# Current Index: 152. The temperature is 47.9
# Current Index: 153. The temperature is 47.9
# Current Index: 154. The temperature is 44.6
# Current Index: 155. The temperature is 49.4
# Current Index: 156. The temperature is 41.5
# Current Index: 157. The temperature is 43.9
# Current Index: 158. The temperature is 45.2
# Current Index: 159. The temperature is 54.7
# Current Index: 160. The temperature is 55.8
# Current Index: 161. The temperature is 68.9
# Current Index: 162. The temperature is 58.3
# Current Index: 163. The temperature is 52.0
# Current Index: 164. The temperature is 46.0
# Current Index: 165. The temperature is 39.5
# Current Index: 166. The temperature is 31.7
# Current Index: 167. The temperature is 32.9
# Current Index: 168. The temperature is 75.8
# Current Index: 169. The temperature is 47.1
# Current Index: 170. The temperature is 32.4
# Current Index: 171. The temperature is 55.9
# Current Index: 172. The temperature is 41.4
# Current Index: 173. The temperature is 69.5
# Current Index: 174. The temperature is 33.7
# Current Index: 175. The temperature is 53.6
# Current Index: 176. The temperature is 29.6
# Current Index: 177. The temperature is 26.0
# Current Index: 178. The temperature is 24.0
# Current Index: 179. The temperature is 25.0
# Current Index: 180. The temperature is 43.6
# Current Index: 181. The temperature is 43.3
# Current Index: 182. The temperature is 45.1
# Current Index: 183. The temperature is 45.6
# Current Index: 184. The temperature is 55.3
# Current Index: 185. The temperature is 53.6
# Current Index: 186. The temperature is 61.3
# Current Index: 187. The temperature is 62.4
# Current Index: 188. The temperature is 57.1
# Current Index: 189. The temperature is 71.9
# Current Index: 190. The temperature is 67.1
# Current Index: 191. The temperature is 60.4
# Current Index: 192. The temperature is 75.1
# Current Index: 193. The temperature is 51.5
# Current Index: 194. The temperature is 66.4
# Current Index: 195. The temperature is 63.1
# Current Index: 196. The temperature is 86.8
# Current Index: 197. The temperature is 88.8
# Current Index: 198. The temperature is 87.9
# Current Index: 199. The temperature is 83.6
# Current Index: 200. The temperature is 84.0
# Current Index: 201. The temperature is 94.2
# Current Index: 202. The temperature is 85.0
# Current Index: 203. The temperature is 65.9
# Current Index: 204. The temperature is 95.1
# Current Index: 205. The temperature is 80.1
# Current Index: 206. The temperature is 89.8
# Current Index: 207. The temperature is 80.8
# Current Index: 208. The temperature is 85.1
# Current Index: 209. The temperature is 85.1
# Current Index: 210. The temperature is 95.0
# Current Index: 211. The temperature is 83.5
# Current Index: 212. The temperature is 98.0
# Current Index: 213. The temperature is 90.8
# Current Index: 214. The temperature is 90.1
# Current Index: 215. The temperature is 87.5
# Current Index: 216. The temperature is 96.4
# Current Index: 217. The temperature is 98.0
# Current Index: 218. The temperature is 103.5
# Current Index: 219. The temperature is 102.4
# Current Index: 220. The temperature is 101.0
# Current Index: 221. The temperature is 91.9
# Current Index: 222. The temperature is 91.9
# Current Index: 223. The temperature is 94.9
# Current Index: 224. The temperature is 85.8
# Current Index: 225. The temperature is 88.8
# Current Index: 226. The temperature is 82.0
# Current Index: 227. The temperature is 57.3
# Current Index: 228. The temperature is 75.9
# Current Index: 229. The temperature is 64.5
# Current Index: 230. The temperature is 46.8
# Current Index: 231. The temperature is 52.2
# Current Index: 232. The temperature is 73.1
# Current Index: 233. The temperature is 64.7
# Current Index: 234. The temperature is 77.2
# Current Index: 235. The temperature is 66.6
# Current Index: 236. The temperature is 55.0
# Current Index: 237. The temperature is 37.7
# Current Index: 238. The temperature is 40.5
# Current Index: 239. The temperature is 41.0
# Current Index: 240. The temperature is 71.3
# Current Index: 241. The temperature is 47.2
# Current Index: 242. The temperature is 38.7
# Current Index: 243. The temperature is 40.5
# Current Index: 244. The temperature is 37.7
# Current Index: 245. The temperature is 21.7
# Current Index: 246. The temperature is 33.0
# Current Index: 247. The temperature is 46.3
# Current Index: 248. The temperature is 38.9
# Current Index: 249. The temperature is 25.2
# Current Index: 250. The temperature is 42.6
# Current Index: 251. The temperature is 41.1
# Current Index: 252. The temperature is 35.6
# Current Index: 253. The temperature is 24.4
# Current Index: 254. The temperature is 41.0
# Current Index: 255. The temperature is 42.7
# Current Index: 256. The temperature is 57.1
# Current Index: 257. The temperature is 52.5
# Current Index: 258. The temperature is 57.0
# Current Index: 259. The temperature is 68.4
# Current Index: 260. The temperature is 88.4
# Current Index: 261. The temperature is 86.1
# Current Index: 262. The temperature is 58.6
# Current Index: 263. The temperature is 89.7
# Current Index: 264. The temperature is 92.0
# Current Index: 265. The temperature is 92.3
# Current Index: 266. The temperature is 79.5
# Current Index: 267. The temperature is 51.3
# Current Index: 268. The temperature is 60.4
# Current Index: 269. The temperature is 58.8
# Current Index: 270. The temperature is 88.8
# Current Index: 271. The temperature is 97.6
# Current Index: 272. The temperature is 86.1
# Current Index: 273. The temperature is 44.4
# Current Index: 274. The temperature is 82.5
# Current Index: 275. The temperature is 85.5
# Current Index: 276. The temperature is 86.2
# Current Index: 277. The temperature is 35.5
# Current Index: 278. The temperature is 74.6
# Current Index: 279. The temperature is 41.2
# Current Index: 280. The temperature is 41.7
# Current Index: 281. The temperature is 59.7
# Current Index: 282. The temperature is 66.4
# Current Index: 283. The temperature is 94.1
# Current Index: 284. The temperature is 51.6
# Current Index: 285. The temperature is 39.8
# Current Index: 286. The temperature is 75.4
# Current Index: 287. The temperature is 85.5
# Current Index: 288. The temperature is 94.9
# Current Index: 289. The temperature is 97.2
# Current Index: 290. The temperature is 94.2
# Current Index: 291. The temperature is 93.8
# Current Index: 292. The temperature is 90.3
# Current Index: 293. The temperature is 95.4
# Skipping Index 294: NO_DATA not found at URL.
# Skipping Index 295: NO_DATA not found at URL.
# Skipping Index 296: Kalorama Triangle not found at URL.
# Current Index: 297. The temperature is 62.2
# Current Index: 298. The temperature is 70.7
# Current Index: 299. The temperature is 70.8
# Current Index: 300. The temperature is 64.2
# Current Index: 301. The temperature is 66.2
# Current Index: 302. The temperature is 46.4
# Current Index: 303. The temperature is 84.3
# Current Index: 304. The temperature is 86.8
# Current Index: 305. The temperature is 86.8
# Current Index: 306. The temperature is 88.1
# Current Index: 307. The temperature is 88.1
# Current Index: 308. The temperature is 95.1
# Current Index: 309. The temperature is 69.2
# Current Index: 310. The temperature is 88.6
# Current Index: 311. The temperature is 43.3
# Current Index: 312. The temperature is 64.7
# Current Index: 313. The temperature is 59.5
# Skipping Index 314: Kalorama Triangle not found at URL.
# Current Index: 315. The temperature is 33.6
# Current Index: 316. The temperature is 10.4
# Current Index: 317. The temperature is 49.3
# Current Index: 318. The temperature is 93.1
# Current Index: 319. The temperature is 39.7
# Current Index: 320. The temperature is 38.1
# Current Index: 321. The temperature is 29.8
# Current Index: 322. The temperature is 17.7
# Current Index: 323. The temperature is 34.6
# Current Index: 324. The temperature is 27.5
# Current Index: 325. The temperature is 32.8
# Current Index: 326. The temperature is 53.2
# Current Index: 327. The temperature is 68.3
# Current Index: 328. The temperature is 68.5
# Current Index: 329. The temperature is 72.5
# Current Index: 330. The temperature is 92.9
# Current Index: 331. The temperature is 78.9
# Current Index: 332. The temperature is 75.7
# Current Index: 333. The temperature is 73.8
# Current Index: 334. The temperature is 69.8
# Current Index: 335. The temperature is 83.7
# Current Index: 336. The temperature is 80.2
# Current Index: 337. The temperature is 83.8
# Current Index: 338. The temperature is 86.3
# Current Index: 339. The temperature is 88.2
# Current Index: 340. The temperature is 83.6
# Current Index: 341. The temperature is 78.2
# Current Index: 342. The temperature is 84.8
# Current Index: 343. The temperature is 88.3
# Current Index: 344. The temperature is 90.0
# Current Index: 345. The temperature is 95.0
# Current Index: 346. The temperature is 90.8
# Current Index: 347. The temperature is 92.2
# Current Index: 348. The temperature is 92.2
# Current Index: 349. The temperature is 74.2
# Current Index: 350. The temperature is 72.6
# Current Index: 351. The temperature is 61.2
# Current Index: 352. The temperature is 59.5
# Current Index: 353. The temperature is 66.4
# Current Index: 354. The temperature is 62.1
# Current Index: 355. The temperature is 60.5
# Current Index: 356. The temperature is -10.4
# Current Index: 357. The temperature is 40.2
# Current Index: 358. The temperature is 92.0
# Current Index: 359. The temperature is 98.2
# Current Index: 360. The temperature is 30.0
# Current Index: 361. The temperature is 26.2
# Current Index: 362. The temperature is 35.2
# Current Index: 363. The temperature is 64.8
# Current Index: 364. The temperature is 64.0
# Current Index: 365. The temperature is 56.1
# Current Index: 366. The temperature is 47.8
# Current Index: 367. The temperature is 34.8
# Current Index: 368. The temperature is 45.6
# Current Index: 369. The temperature is 75.2
# Current Index: 370. The temperature is 55.9
# Current Index: 371. The temperature is 69.2
# Current Index: 372. The temperature is 72.9
# Current Index: 373. The temperature is 70.5
# Current Index: 374. The temperature is 68.5
# Current Index: 375. The temperature is 68.8
# Current Index: 376. The temperature is 60.8
# Current Index: 377. The temperature is 57.3
# Current Index: 378. The temperature is 63.5
# Current Index: 379. The temperature is 46.3
# Current Index: 380. The temperature is 92.5
# Current Index: 381. The temperature is 55.0
# Current Index: 382. The temperature is 43.9
# Current Index: 383. The temperature is 80.0
# Current Index: 384. The temperature is 75.5
# Current Index: 385. The temperature is 71.8
# Current Index: 386. The temperature is 61.3
# Skipping Index 387: SOMISSPO not found at URL.
# Current Index: 388. The temperature is 30.0
# Current Index: 389. The temperature is 58.2
# Current Index: 390. The temperature is 58.7
# Current Index: 391. The temperature is 82.5
# Current Index: 392. The temperature is 70.0
# Current Index: 393. The temperature is 21.1
# Current Index: 394. The temperature is 56.9
# Current Index: 395. The temperature is 55.4
# Current Index: 396. The temperature is 62.7
# Current Index: 397. The temperature is 41.2
# Current Index: 398. The temperature is 35.9
# Current Index: 399. The temperature is 29.6
# Current Index: 400. The temperature is 73.8
# Current Index: 401. The temperature is 38.0
# Current Index: 402. The temperature is 89.0
# Current Index: 403. The temperature is 28.1
# Current Index: 404. The temperature is 55.0
# Current Index: 405. The temperature is 49.9
# Current Index: 406. The temperature is 44.1
# Current Index: 407. The temperature is 37.2
# Current Index: 408. The temperature is 57.1
# Current Index: 409. The temperature is 67.1
# Current Index: 410. The temperature is 76.6
# Current Index: 411. The temperature is 73.7
# Current Index: 412. The temperature is 80.5
# Current Index: 413. The temperature is 58.7
# Current Index: 414. The temperature is 31.7
# Current Index: 415. The temperature is 27.2
# Current Index: 416. The temperature is 37.5
# Current Index: 417. The temperature is 81.7
# Current Index: 418. The temperature is 51.9
# Current Index: 419. The temperature is 64.3
# Current Index: 420. The temperature is 64.3
# Current Index: 421. The temperature is 56.1
# Current Index: 422. The temperature is 60.3
# Current Index: 423. The temperature is 63.7
# Current Index: 424. The temperature is 66.2
# Current Index: 425. The temperature is 95.5
# Current Index: 426. The temperature is 101.3
# Current Index: 427. The temperature is 96.6
# Current Index: 428. The temperature is 102.6
# Current Index: 429. The temperature is 89.6
# Current Index: 430. The temperature is 99.8
# Current Index: 431. The temperature is 99.1
# Current Index: 432. The temperature is 92.8
# Current Index: 433. The temperature is 96.7
# Current Index: 434. The temperature is 93.3
# Current Index: 435. The temperature is 89.1
# Current Index: 436. The temperature is 89.1
# Current Index: 437. The temperature is 81.9
# Current Index: 438. The temperature is 87.6
# Current Index: 439. The temperature is 87.7
# Current Index: 440. The temperature is 87.7
# Current Index: 441. The temperature is 64.6
# Current Index: 442. The temperature is 64.6
# Current Index: 443. The temperature is 61.9
# Skipping Index 444: Noorpur Shahan not found at URL.
# Skipping Index 445: Noorpur Shahan not found at URL.
# Skipping Index 446: Noorpur Shahan not found at URL.
# Current Index: 447. The temperature is 99.6
# Current Index: 448. The temperature is 63.2
# Skipping Index 449: NO_DATA not found at URL.
# Skipping Index 450: NO_DATA not found at URL.
# Skipping Index 451: NO_DATA not found at URL.
# Skipping Index 452: NO_DATA not found at URL.
# Skipping Index 453: NO_DATA not found at URL.
# Skipping Index 454: NO_DATA not found at URL.
# Skipping Index 455: NO_DATA not found at URL.
# Skipping Index 456: NO_DATA not found at URL.
# Skipping Index 457: NO_DATA not found at URL.
# Skipping Index 458: NO_DATA not found at URL.
# Skipping Index 459: NO_DATA not found at URL.
# Skipping Index 460: NO_DATA not found at URL.
# Skipping Index 461: NO_DATA not found at URL.
# Skipping Index 462: NO_DATA not found at URL.
# Skipping Index 463: NO_DATA not found at URL.
# Skipping Index 464: NO_DATA not found at URL.
# Skipping Index 465: NO_DATA not found at URL.
# Skipping Index 466: NO_DATA not found at URL.
# Skipping Index 467: NO_DATA not found at URL.
# Skipping Index 468: NO_DATA not found at URL.
# Skipping Index 469: NO_DATA not found at URL.
# Skipping Index 470: NO_DATA not found at URL.
# Skipping Index 471: NO_DATA not found at URL.
# Skipping Index 472: NO_DATA not found at URL.
# Skipping Index 473: NO_DATA not found at URL.
# Skipping Index 474: NO_DATA not found at URL.
# Skipping Index 475: NO_DATA not found at URL.
# Skipping Index 476: NO_DATA not found at URL.
# Current Index: 477. The temperature is 66.1
# Current Index: 478. The temperature is -12.1
# Current Index: 479. The temperature is 78.2
# Current Index: 480. The temperature is 72.3
# Current Index: 481. The temperature is 4.5
# Current Index: 482. The temperature is 71.0
# Current Index: 483. The temperature is 12.3
# Current Index: 484. The temperature is 83.8
# Skipping Index 485: Kalorama Triangle not found at URL.
# Current Index: 486. The temperature is 71.7
# Current Index: 487. The temperature is 88.9
# Current Index: 488. The temperature is 72.8
# Current Index: 489. The temperature is 78.9
# Current Index: 490. The temperature is 64.6
# Current Index: 491. The temperature is 65.9
# Current Index: 492. The temperature is 78.9
# Current Index: 493. The temperature is 75.6
# Current Index: 494. The temperature is 80.7
# Current Index: 495. The temperature is 76.0
# Current Index: 496. The temperature is 72.5
# Current Index: 497. The temperature is 70.0
# Current Index: 498. The temperature is 79.5
# Current Index: 499. The temperature is 80.8
# Current Index: 500. The temperature is 80.8
# Current Index: 501. The temperature is 80.8
# Current Index: 502. The temperature is 79.7
# Current Index: 503. The temperature is 75.2
# Current Index: 504. The temperature is 75.8
# Current Index: 505. The temperature is 79.0
# Current Index: 506. The temperature is 83.8
# Current Index: 507. The temperature is 83.5
# Current Index: 508. The temperature is 77.4
# Current Index: 509. The temperature is 70.8
# Skipping Index 510: NO_DATA not found at URL.
# Skipping Index 511: NO_DATA not found at URL.
# Skipping Index 512: NO_DATA not found at URL.
# Skipping Index 513: NO_DATA not found at URL.
# Skipping Index 514: NO_DATA not found at URL.
# Skipping Index 515: NO_DATA not found at URL.
# Current Index: 516. The temperature is 90.6
# Current Index: 517. The temperature is 93.9
# Current Index: 518. The temperature is 95.4
# Current Index: 519. The temperature is 91.3
# Current Index: 520. The temperature is 76.2
# Current Index: 521. The temperature is 94.5
# Current Index: 522. The temperature is 91.3
# Current Index: 523. The temperature is 97.4
# Current Index: 524. The temperature is 105.6
# Current Index: 525. The temperature is 95.4
# Current Index: 526. The temperature is 98.7
# Current Index: 527. The temperature is 98.3
# Current Index: 528. The temperature is 94.5
# Current Index: 529. The temperature is 91.7
# Current Index: 530. The temperature is 93.8
# Skipping Index 531: Savon Height not found at URL.
# Current Index: 532. The temperature is 69.1
# Current Index: 533. The temperature is 56.2
# Current Index: 534. The temperature is 47.5
# Current Index: 535. The temperature is 68.7
# Current Index: 536. The temperature is 92.1
# Current Index: 537. The temperature is 88.7
# Current Index: 538. The temperature is 78.9
# Current Index: 539. The temperature is 85.3
# Current Index: 540. The temperature is 74.3
# Current Index: 541. The temperature is 77.4
# Current Index: 542. The temperature is 75.2
# Current Index: 543. The temperature is 72.3
# Current Index: 544. The temperature is 70.4
# Current Index: 545. The temperature is 84.5
# Current Index: 546. The temperature is 88.9
# Current Index: 547. The temperature is 102.5
# Current Index: 548. The temperature is 102.1
# Current Index: 549. The temperature is 101.2
# Current Index: 550. The temperature is 100.3
# Current Index: 551. The temperature is 86.3
# Current Index: 552. The temperature is 89.1
# Current Index: 553. The temperature is 100.4
# Current Index: 554. The temperature is 97.3
# Current Index: 555. The temperature is 97.2
# Current Index: 556. The temperature is 91.8
# Current Index: 557. The temperature is 91.8
# Current Index: 558. The temperature is 56.1
# Current Index: 559. The temperature is 52.1
# Current Index: 560. The temperature is 55.3
# Current Index: 561. The temperature is 61.2
# Current Index: 562. The temperature is 67.4
# Current Index: 563. The temperature is 69.0
# Current Index: 564. The temperature is 67.7
# Current Index: 565. The temperature is 59.5
# Current Index: 566. The temperature is 53.7
# Current Index: 567. The temperature is 53.2
# Current Index: 568. The temperature is 59.7
# Current Index: 569. The temperature is 54.6
# Current Index: 570. The temperature is 43.9
# Current Index: 571. The temperature is 50.8
# Current Index: 572. The temperature is 56.8
# Current Index: 573. The temperature is 60.5
# Skipping Index 574: NO_DATA not found at URL.
# Skipping Index 575: NO_DATA not found at URL.
# Skipping Index 576: NO_DATA not found at URL.
# Skipping Index 577: NO_DATA not found at URL.
# Skipping Index 578: NO_DATA not found at URL.
# Skipping Index 579: NO_DATA not found at URL.
# Skipping Index 580: NO_DATA not found at URL.
# Skipping Index 581: NO_DATA not found at URL.
# Skipping Index 582: NO_DATA not found at URL.
# Current Index: 583. The temperature is 87.1
# Current Index: 584. The temperature is 73.8
# Current Index: 585. The temperature is 25.6
# Current Index: 586. The temperature is 96.8
# Current Index: 587. The temperature is 70.1
# Current Index: 588. The temperature is 41.3
# Current Index: 589. The temperature is 55.6
# Current Index: 590. The temperature is 92.9
# Current Index: 591. The temperature is 105.0
# Current Index: 592. The temperature is 95.0
# Current Index: 593. The temperature is 4.7
# Current Index: 594. The temperature is 62.5
# Current Index: 595. The temperature is 92.5
# Current Index: 596. The temperature is 80.8
# Current Index: 597. The temperature is 36.2
# Current Index: 598. The temperature is 90.0
# Current Index: 599. The temperature is 60.7
# Current Index: 600. The temperature is 93.5
# Current Index: 601. The temperature is 52.0
# Current Index: 602. The temperature is 71.7
# Current Index: 603. The temperature is 61.2
# Current Index: 604. The temperature is 51.0
# Current Index: 605. The temperature is 72.8
# Current Index: 606. The temperature is 23.2
# Current Index: 607. The temperature is 53.6
# Current Index: 608. The temperature is 101.0
# Current Index: 609. The temperature is 94.8
# Current Index: 610. The temperature is 60.7
# Current Index: 611. The temperature is 96.6
# Current Index: 612. The temperature is 97.9
# Current Index: 613. The temperature is 52.7
# Current Index: 614. The temperature is 61.5
# Current Index: 615. The temperature is 21.3
# Current Index: 616. The temperature is 30.9
# Current Index: 617. The temperature is 33.4
# Current Index: 618. The temperature is 36.7
# Current Index: 619. The temperature is 33.8
# Current Index: 620. The temperature is 47.5
# Current Index: 621. The temperature is 45.1
# Current Index: 622. The temperature is 34.2
# Current Index: 623. The temperature is 30.0
# Current Index: 624. The temperature is 21.6
# Current Index: 625. The temperature is 2.4
# Current Index: 626. The temperature is 51.7
# Current Index: 627. The temperature is 57.5
# Current Index: 628. The temperature is 30.1
# Current Index: 629. The temperature is 29.1
# Current Index: 630. The temperature is 23.2
# Current Index: 631. The temperature is 21.4
# Current Index: 632. The temperature is 42.6
# Current Index: 633. The temperature is 41.5
# Current Index: 634. The temperature is 44.9
# Current Index: 635. The temperature is 56.0
# Current Index: 636. The temperature is 54.7
# Current Index: 637. The temperature is 58.1
# Current Index: 638. The temperature is 62.5
# Current Index: 639. The temperature is 68.0
# Current Index: 640. The temperature is 57.9
# Current Index: 641. The temperature is 72.6
# Current Index: 642. The temperature is 55.6
# Current Index: 643. The temperature is 62.2
# Current Index: 644. The temperature is 87.1
# Current Index: 645. The temperature is 79.0
# Current Index: 646. The temperature is 91.8
# Current Index: 647. The temperature is 90.2
# Current Index: 648. The temperature is 67.4
# Current Index: 649. The temperature is 93.4
# Current Index: 650. The temperature is 87.5
# Current Index: 651. The temperature is 68.3
# Current Index: 652. The temperature is 90.8
# Current Index: 653. The temperature is 80.1
# Current Index: 654. The temperature is 79.1
# Current Index: 655. The temperature is 89.9
# Current Index: 656. The temperature is 86.7
# Current Index: 657. The temperature is 95.9
# Current Index: 658. The temperature is 99.1
# Current Index: 659. The temperature is 89.9
# Current Index: 660. The temperature is 94.1
# Current Index: 661. The temperature is 88.6
# Current Index: 662. The temperature is 93.4
# Current Index: 663. The temperature is 97.2
# Current Index: 664. The temperature is 102.5
# Current Index: 665. The temperature is 101.5
# Current Index: 666. The temperature is 96.4
# Current Index: 667. The temperature is 93.7
# Current Index: 668. The temperature is 96.6
# Current Index: 669. The temperature is 93.6
# Current Index: 670. The temperature is 86.3
# Current Index: 671. The temperature is 89.2
# Current Index: 672. The temperature is 81.2
# Current Index: 673. The temperature is 96.2
# Current Index: 674. The temperature is 65.1
# Current Index: 675. The temperature is 74.4
# Current Index: 676. The temperature is 53.8
# Current Index: 677. The temperature is 66.9
# Current Index: 678. The temperature is 62.2
# Current Index: 679. The temperature is 79.2
# Current Index: 680. The temperature is 70.7
# Current Index: 681. The temperature is 56.2
# Current Index: 682. The temperature is 55.8
# Current Index: 683. The temperature is 42.5
# Current Index: 684. The temperature is 46.6
# Current Index: 685. The temperature is 49.6
# Current Index: 686. The temperature is 39.7
# Current Index: 687. The temperature is 38.0
# Current Index: 688. The temperature is 29.9
# Current Index: 689. The temperature is 32.2
# Current Index: 690. The temperature is 52.4
# Current Index: 691. The temperature is 44.4
# Current Index: 692. The temperature is 26.8
# Current Index: 693. The temperature is 62.9
# Current Index: 694. The temperature is 30.6
# Current Index: 695. The temperature is 47.7
# Current Index: 696. The temperature is 46.6
# Current Index: 697. The temperature is 44.4
# Current Index: 698. The temperature is 98.0
# Current Index: 699. The temperature is 98.7
# Current Index: 700. The temperature is 58.9
# Current Index: 701. The temperature is 67.0
# Current Index: 702. The temperature is 77.2
# Current Index: 703. The temperature is 28.0
# Current Index: 704. The temperature is 59.4
# Current Index: 705. The temperature is 93.5
# Current Index: 706. The temperature is 92.7
# Current Index: 707. The temperature is 70.4
# Skipping Index 708: NO_DATA not found at URL.
# Current Index: 709. The temperature is 40.4
# Current Index: 710. The temperature is 62.6
# Current Index: 711. The temperature is 87.5
# Current Index: 712. The temperature is 97.2
# Current Index: 713. The temperature is 92.4
# Current Index: 714. The temperature is 90.0
# Current Index: 715. The temperature is 91.5
# Current Index: 716. The temperature is 98.3
# Current Index: 717. The temperature is 93.4
# Current Index: 718. The temperature is 92.3
# Current Index: 719. The temperature is 97.3
# Current Index: 720. The temperature is 97.6
# Current Index: 721. The temperature is 2.4
# Current Index: 722. The temperature is -4.5
# Current Index: 723. The temperature is 84.9
# Current Index: 724. The temperature is 88.9
# Current Index: 725. The temperature is 62.4
# Current Index: 726. The temperature is 55.1
# Current Index: 727. The temperature is 78.4
# Current Index: 728. The temperature is 77.5
# Current Index: 729. The temperature is 19.1
# Current Index: 730. The temperature is 67.1
# Skipping Index 731: NO_DATA not found at URL.
# Skipping Index 732: NO_DATA not found at URL.
# Skipping Index 733: NO_DATA not found at URL.
# Skipping Index 734: NO_DATA not found at URL.
# Current Index: 735. The temperature is 73.7
# Current Index: 736. The temperature is 64.6
# Current Index: 737. The temperature is 70.5
# Current Index: 738. The temperature is 65.4
# Current Index: 739. The temperature is 28.6
# Current Index: 740. The temperature is 31.8
# Current Index: 741. The temperature is 88.4
# Current Index: 742. The temperature is 59.9
# Current Index: 743. The temperature is 61.0
# Current Index: 744. The temperature is 52.0
# Current Index: 745. The temperature is 59.1
# Current Index: 746. The temperature is 60.4
# Current Index: 747. The temperature is 67.4
# Current Index: 748. The temperature is 66.1
# Current Index: 749. The temperature is 72.2
# Current Index: 750. The temperature is 90.2
# Current Index: 751. The temperature is 86.4
# Current Index: 752. The temperature is 81.0
# Current Index: 753. The temperature is 77.1
# Current Index: 754. The temperature is 84.0
# Current Index: 755. The temperature is 89.4
# Current Index: 756. The temperature is 78.8
# Current Index: 757. The temperature is 70.9
# Current Index: 758. The temperature is 71.1
# Current Index: 759. The temperature is 57.5
# Skipping Index 760: Savon Height not found at URL.
# Current Index: 761. The temperature is 34.4
# Current Index: 762. The temperature is 55.5
# Current Index: 763. The temperature is 43.4
# Current Index: 764. The temperature is 42.1
# Current Index: 765. The temperature is 43.3
# Current Index: 766. The temperature is 75.5
# Current Index: 767. The temperature is 55.2
# Current Index: 768. The temperature is 97.2
# Current Index: 769. The temperature is 97.4
# Current Index: 770. The temperature is 57.9
# Current Index: 771. The temperature is 58.9
# Current Index: 772. The temperature is 58.9
# Current Index: 773. The temperature is 71.6
# Current Index: 774. The temperature is 63.2
# Current Index: 775. The temperature is 99.4
# Current Index: 776. The temperature is 23.8
# Current Index: 777. The temperature is 25.1
# Current Index: 778. The temperature is 37.4
# Current Index: 779. The temperature is 48.8
# Current Index: 780. The temperature is 52.9
# Current Index: 781. The temperature is 29.8
# Current Index: 782. The temperature is 66.1
# Current Index: 783. The temperature is 92.2
# Current Index: 784. The temperature is 66.3
# Current Index: 785. The temperature is 94.3
# Skipping Index 786: NO_DATA not found at URL.
# Skipping Index 787: NO_DATA not found at URL.
# Skipping Index 788: NO_DATA not found at URL.
# Skipping Index 789: NO_DATA not found at URL.
# Skipping Index 790: NO_DATA not found at URL.
# Skipping Index 791: NO_DATA not found at URL.
# Skipping Index 792: NO_DATA not found at URL.
# Skipping Index 793: NO_DATA not found at URL.
# Skipping Index 794: NO_DATA not found at URL.
# Current Index: 795. The temperature is 20.6
# Current Index: 796. The temperature is 33.0
# Current Index: 797. The temperature is 40.4
# Current Index: 798. The temperature is 38.7
# Current Index: 799. The temperature is 29.0
# Current Index: 800. The temperature is 40.2
# Current Index: 801. The temperature is 40.8
# Current Index: 802. The temperature is 39.8
# Current Index: 803. The temperature is 53.2
# Current Index: 804. The temperature is 53.8
# Current Index: 805. The temperature is 52.0
# Current Index: 806. The temperature is 65.4
# Current Index: 807. The temperature is 87.2
# Current Index: 808. The temperature is 87.6
# Current Index: 809. The temperature is 60.2
# Current Index: 810. The temperature is 90.9
# Current Index: 811. The temperature is 93.3
# Current Index: 812. The temperature is 83.5
# Current Index: 813. The temperature is 91.3
# Current Index: 814. The temperature is 79.1
# Current Index: 815. The temperature is 54.0
# Current Index: 816. The temperature is 48.0
# Current Index: 817. The temperature is 69.5
# Current Index: 818. The temperature is 23.8
# Current Index: 819. The temperature is 64.8
# Current Index: 820. The temperature is 94.4
# Current Index: 821. The temperature is 63.0
# Current Index: 822. The temperature is 42.6
# Current Index: 823. The temperature is 42.8
# Current Index: 824. The temperature is 60.0
# Current Index: 825. The temperature is 57.0
# Skipping Index 826: NO_DATA not found at URL.
# Skipping Index 827: NO_DATA not found at URL.
# Skipping Index 828: NO_DATA not found at URL.
# Current Index: 829. The temperature is 60.8
# Current Index: 830. The temperature is 53.1
# Current Index: 831. The temperature is 39.4
# Current Index: 832. The temperature is 53.0
# Current Index: 833. The temperature is 68.3
# Current Index: 834. The temperature is 68.5
# Current Index: 835. The temperature is 65.5
# Current Index: 836. The temperature is 71.4
# Current Index: 837. The temperature is 60.5
# Current Index: 838. The temperature is 65.3
# Current Index: 839. The temperature is 56.5
# Current Index: 840. The temperature is 60.3
# Current Index: 841. The temperature is 61.9
# Current Index: 842. The temperature is 74.9
# Current Index: 843. The temperature is 74.5
# Current Index: 844. The temperature is 68.0
# Current Index: 845. The temperature is 49.3
# Current Index: 846. The temperature is 69.6
# Current Index: 847. The temperature is 41.5
# Current Index: 848. The temperature is 52.4
# Current Index: 849. The temperature is 42.7
# Current Index: 850. The temperature is 31.4
# Current Index: 851. The temperature is 29.6
# Current Index: 852. The temperature is 31.6
# Current Index: 853. The temperature is 47.4
# Current Index: 854. The temperature is 74.1
# Current Index: 855. The temperature is 78.3
# Current Index: 856. The temperature is 62.4
# Current Index: 857. The temperature is 86.8
# Current Index: 858. The temperature is 72.1
# Current Index: 859. The temperature is 41.1
# Current Index: 860. The temperature is 59.3
# Current Index: 861. The temperature is 54.3
# Current Index: 862. The temperature is 76.2
# Current Index: 863. The temperature is 87.6
# Current Index: 864. The temperature is 86.3
# Current Index: 865. The temperature is 74.2
# Current Index: 866. The temperature is 69.5
# Current Index: 867. The temperature is 67.7
# Current Index: 868. The temperature is 92.6
# Current Index: 869. The temperature is 59.3
# Current Index: 870. The temperature is 68.9
# Current Index: 871. The temperature is 68.2
# Current Index: 872. The temperature is 55.6
# Current Index: 873. The temperature is 53.2
# Current Index: 874. The temperature is 53.3
# Current Index: 875. The temperature is 79.9
# Current Index: 876. The temperature is 60.3
# Current Index: 877. The temperature is 9.5
# Current Index: 878. The temperature is 27.2
# Current Index: 879. The temperature is 28.7
# Current Index: 880. The temperature is 39.1
# Skipping Index 881: SOMISSPO not found at URL.
# Current Index: 882. The temperature is 56.2
# Current Index: 883. The temperature is 61.6
# Current Index: 884. The temperature is 56.2
# Current Index: 885. The temperature is 64.8
# Current Index: 886. The temperature is 64.4
# Current Index: 887. The temperature is 67.8
# Current Index: 888. The temperature is 81.2
# Current Index: 889. The temperature is 61.4
# Current Index: 890. The temperature is 75.1
# Current Index: 891. The temperature is 71.9
# Current Index: 892. The temperature is 93.8
# Current Index: 893. The temperature is 23.4
# Current Index: 894. The temperature is 53.5
# Current Index: 895. The temperature is 40.0
# Current Index: 896. The temperature is 69.5
# Current Index: 897. The temperature is 57.3
# Current Index: 898. The temperature is 61.8
# Current Index: 899. The temperature is 52.2
# Current Index: 900. The temperature is 68.2
# Current Index: 901. The temperature is 98.2
# Current Index: 902. The temperature is 97.9
# Current Index: 903. The temperature is 98.0
# Current Index: 904. The temperature is 96.6
# Current Index: 905. The temperature is 101.4
# Current Index: 906. The temperature is 103.6
# Current Index: 907. The temperature is 101.8
# Current Index: 908. The temperature is 84.2
# Current Index: 909. The temperature is 99.1
# Current Index: 910. The temperature is 95.8
# Current Index: 911. The temperature is 95.5
# Current Index: 912. The temperature is 89.8
# Current Index: 913. The temperature is 97.0
# Current Index: 914. The temperature is 97.2
# Current Index: 915. The temperature is 94.0
# Current Index: 916. The temperature is 86.7
# Current Index: 917. The temperature is 78.8
# Current Index: 918. The temperature is 81.9
# Current Index: 919. The temperature is 84.4
# Current Index: 920. The temperature is 52.6
# Current Index: 921. The temperature is 55.3
# Current Index: 922. The temperature is 65.4
# Current Index: 923. The temperature is 61.9
# Current Index: 924. The temperature is 80.0
# Current Index: 925. The temperature is 60.3
# Current Index: 926. The temperature is 79.6
# Current Index: 927. The temperature is 71.4
# Current Index: 928. The temperature is 77.1
# Current Index: 929. The temperature is 75.2
# Current Index: 930. The temperature is 78.2
# Current Index: 931. The temperature is 89.4
# Current Index: 932. The temperature is 89.8
# Current Index: 933. The temperature is 85.6
# Current Index: 934. The temperature is 93.0
# Current Index: 935. The temperature is 102.1
# Current Index: 936. The temperature is 99.6
# Current Index: 937. The temperature is 93.8
# Current Index: 938. The temperature is 93.7
# Current Index: 939. The temperature is 98.7
# Current Index: 940. The temperature is 67.3
# Current Index: 941. The temperature is 44.4
# Current Index: 942. The temperature is 64.0
# Skipping Index 943: Noorpur Shahan not found at URL.
# Skipping Index 944: Noorpur Shahan not found at URL.
# Current Index: 945. The temperature is 90.1
# Current Index: 946. The temperature is 54.9
# Current Index: 947. The temperature is 63.7
# Current Index: 948. The temperature is 90.6
# Current Index: 949. The temperature is 95.3
# Current Index: 950. The temperature is 88.2
# Current Index: 951. The temperature is 79.7
# Current Index: 952. The temperature is 82.4
# Current Index: 953. The temperature is 74.1
# Current Index: 954. The temperature is 82.0
# Current Index: 955. The temperature is 63.8
# Current Index: 956. The temperature is 60.6
# Current Index: 957. The temperature is 50.3
# Skipping Index 958: NO_DATA not found at URL.
# Skipping Index 959: NO_DATA not found at URL.
# Skipping Index 960: NO_DATA not found at URL.
# Skipping Index 961: NO_DATA not found at URL.
# Skipping Index 962: NO_DATA not found at URL.
# Skipping Index 963: NO_DATA not found at URL.
# Skipping Index 964: NO_DATA not found at URL.
# Skipping Index 965: NO_DATA not found at URL.
# Skipping Index 966: NO_DATA not found at URL.
# Skipping Index 967: NO_DATA not found at URL.
# Skipping Index 968: NO_DATA not found at URL.
# Skipping Index 969: NO_DATA not found at URL.
# Skipping Index 970: NO_DATA not found at URL.
# Skipping Index 971: NO_DATA not found at URL.
# Skipping Index 972: NO_DATA not found at URL.
# Skipping Index 973: NO_DATA not found at URL.
# Skipping Index 974: NO_DATA not found at URL.
# Skipping Index 975: NO_DATA not found at URL.
# Skipping Index 976: NO_DATA not found at URL.
# Skipping Index 977: NO_DATA not found at URL.
# Skipping Index 978: NO_DATA not found at URL.
# Skipping Index 979: NO_DATA not found at URL.
# Skipping Index 980: NO_DATA not found at URL.
# Skipping Index 981: NO_DATA not found at URL.
# Skipping Index 982: NO_DATA not found at URL.
# Skipping Index 983: NO_DATA not found at URL.
# Skipping Index 984: NO_DATA not found at URL.
# Skipping Index 985: NO_DATA not found at URL.
# Skipping Index 986: NO_DATA not found at URL.
# Skipping Index 987: NO_DATA not found at URL.
# Skipping Index 988: NO_DATA not found at URL.
# Skipping Index 989: NO_DATA not found at URL.
# Skipping Index 990: NO_DATA not found at URL.
# Skipping Index 991: NO_DATA not found at URL.
# Skipping Index 992: NO_DATA not found at URL.
# Skipping Index 993: NO_DATA not found at URL.
# Skipping Index 994: NO_DATA not found at URL.
# Skipping Index 995: NO_DATA not found at URL.
# Skipping Index 996: NO_DATA not found at URL.
# Skipping Index 997: NO_DATA not found at URL.
# Skipping Index 998: NO_DATA not found at URL.
# Skipping Index 999: NO_DATA not found at URL.
# Skipping Index 1000: NO_DATA not found at URL.
# Skipping Index 1001: NO_DATA not found at URL.
# Skipping Index 1002: NO_DATA not found at URL.
# Skipping Index 1003: NO_DATA not found at URL.
# Skipping Index 1004: NO_DATA not found at URL.
# Skipping Index 1005: NO_DATA not found at URL.
# Skipping Index 1006: NO_DATA not found at URL.
# Skipping Index 1007: NO_DATA not found at URL.
# Skipping Index 1008: NO_DATA not found at URL.
# Skipping Index 1009: NO_DATA not found at URL.
# Skipping Index 1010: NO_DATA not found at URL.
# Skipping Index 1011: NO_DATA not found at URL.
# Skipping Index 1012: NO_DATA not found at URL.
# Skipping Index 1013: NO_DATA not found at URL.
# Skipping Index 1014: NO_DATA not found at URL.
# Skipping Index 1015: NO_DATA not found at URL.
# Skipping Index 1016: NO_DATA not found at URL.
# Skipping Index 1017: NO_DATA not found at URL.
# Skipping Index 1018: NO_DATA not found at URL.
# Skipping Index 1019: NO_DATA not found at URL.
# Skipping Index 1020: NO_DATA not found at URL.
# Skipping Index 1021: NO_DATA not found at URL.
# Skipping Index 1022: NO_DATA not found at URL.
# Skipping Index 1023: NO_DATA not found at URL.
# Skipping Index 1024: NO_DATA not found at URL.
# Skipping Index 1025: NO_DATA not found at URL.
# Skipping Index 1026: NO_DATA not found at URL.
# Skipping Index 1027: NO_DATA not found at URL.
# Skipping Index 1028: NO_DATA not found at URL.
# Skipping Index 1029: NO_DATA not found at URL.
# Skipping Index 1030: NO_DATA not found at URL.
# Skipping Index 1031: NO_DATA not found at URL.
# Skipping Index 1032: NO_DATA not found at URL.
# Skipping Index 1033: NO_DATA not found at URL.
# Skipping Index 1034: NO_DATA not found at URL.
# Skipping Index 1035: NO_DATA not found at URL.
# Skipping Index 1036: NO_DATA not found at URL.
# Skipping Index 1037: NO_DATA not found at URL.
# Skipping Index 1038: NO_DATA not found at URL.
# Skipping Index 1039: NO_DATA not found at URL.
# Skipping Index 1040: NO_DATA not found at URL.
# Skipping Index 1041: NO_DATA not found at URL.
# Skipping Index 1042: NO_DATA not found at URL.
# Skipping Index 1043: NO_DATA not found at URL.
# Current Index: 1044. The temperature is 58.3
# Current Index: 1045. The temperature is 40.9
# Current Index: 1046. The temperature is 92.7
# Current Index: 1047. The temperature is 78.0
# Current Index: 1048. The temperature is 97.6
# Current Index: 1049. The temperature is 20.4
# Current Index: 1050. The temperature is 19.8
# Current Index: 1051. The temperature is 31.8
# Current Index: 1052. The temperature is 36.3
# Current Index: 1053. The temperature is 59.1
# Current Index: 1054. The temperature is 48.0
# Current Index: 1055. The temperature is 25.6
# Current Index: 1056. The temperature is 27.1
# Current Index: 1057. The temperature is 35.4
# Current Index: 1058. The temperature is 40.2
# Current Index: 1059. The temperature is 90.3
# Current Index: 1060. The temperature is 65.0
# Current Index: 1061. The temperature is 40.6
# Current Index: 1062. The temperature is 67.4
# Current Index: 1063. The temperature is 70.9
# Current Index: 1064. The temperature is 70.0
# Current Index: 1065. The temperature is 58.1
# Current Index: 1066. The temperature is 91.1
# Current Index: 1067. The temperature is 76.1
# Current Index: 1068. The temperature is 37.2
# Current Index: 1069. The temperature is 33.7
# Current Index: 1070. The temperature is 73.1
# Current Index: 1071. The temperature is 93.0
# Current Index: 1072. The temperature is 54.3
# Current Index: 1073. The temperature is 39.7
# Current Index: 1074. The temperature is 20.8
# Current Index: 1075. The temperature is 30.3
# Current Index: 1076. The temperature is 27.3
# Current Index: 1077. The temperature is 29.9
# Current Index: 1078. The temperature is 34.9
# Current Index: 1079. The temperature is 39.8
# Current Index: 1080. The temperature is 40.6
# Current Index: 1081. The temperature is 50.9
# Current Index: 1082. The temperature is 52.7
# Current Index: 1083. The temperature is 54.4
# Current Index: 1084. The temperature is 56.9
# Current Index: 1085. The temperature is 40.4
# Current Index: 1086. The temperature is 39.0
# Current Index: 1087. The temperature is 86.7
# Current Index: 1088. The temperature is 84.7
# Current Index: 1089. The temperature is 37.3
# Current Index: 1090. The temperature is 29.1
# Current Index: 1091. The temperature is 56.9
# Current Index: 1092. The temperature is 53.2
# Current Index: 1093. The temperature is 58.0
# Current Index: 1094. The temperature is 41.8
# Current Index: 1095. The temperature is 23.9
# Current Index: 1096. The temperature is 24.0
# Current Index: 1097. The temperature is 35.1
# Current Index: 1098. The temperature is 56.2
# Current Index: 1099. The temperature is 81.1
# Current Index: 1100. The temperature is 69.9
# Current Index: 1101. The temperature is 27.0
# Current Index: 1102. The temperature is 66.6
# Current Index: 1103. The temperature is 54.2
# Current Index: 1104. The temperature is 14.3
# Current Index: 1105. The temperature is 99.6
# Current Index: 1106. The temperature is 45.0
# Current Index: 1107. The temperature is 51.7
# Current Index: 1108. The temperature is 87.8
# Current Index: 1109. The temperature is 91.8
# Current Index: 1110. The temperature is 53.0
# Current Index: 1111. The temperature is 62.6
# Current Index: 1112. The temperature is 31.3
# Current Index: 1113. The temperature is 33.3
# Current Index: 1114. The temperature is 39.4
# Current Index: 1115. The temperature is 69.0
# Current Index: 1116. The temperature is 65.4
# Skipping Index 1117: Savon Height not found at URL.
# Skipping Index 1118: Savon Height not found at URL.
# Current Index: 1119. The temperature is 92.7
# Current Index: 1120. The temperature is 30.6
# Current Index: 1121. The temperature is 44.6
# Current Index: 1122. The temperature is 31.1
# Current Index: 1123. The temperature is 54.2
# Current Index: 1124. The temperature is 41.8
# Current Index: 1125. The temperature is 65.6
# Current Index: 1126. The temperature is 62.6
# Current Index: 1127. The temperature is 63.0
# Current Index: 1128. The temperature is 53.8
# Current Index: 1129. The temperature is 37.5
# Current Index: 1130. The temperature is 38.3
# Current Index: 1131. The temperature is 62.1
# Current Index: 1132. The temperature is 53.5
# Current Index: 1133. The temperature is 75.8
# Current Index: 1134. The temperature is 83.7
# Current Index: 1135. The temperature is 72.0
# Current Index: 1136. The temperature is 84.3
# Current Index: 1137. The temperature is 91.9
# Current Index: 1138. The temperature is 96.2
# Current Index: 1139. The temperature is 98.5
# Current Index: 1140. The temperature is 99.2
# Current Index: 1141. The temperature is 93.8
# Current Index: 1142. The temperature is 96.4
# Current Index: 1143. The temperature is 78.9
# Current Index: 1144. The temperature is 79.8
# Current Index: 1145. The temperature is 31.8
# Current Index: 1146. The temperature is 41.0
# Current Index: 1147. The temperature is 52.3
# Current Index: 1148. The temperature is 36.3
# Current Index: 1149. The temperature is 35.2
# Current Index: 1150. The temperature is 35.2
# Current Index: 1151. The temperature is 34.5
# Current Index: 1152. The temperature is 26.2
# Current Index: 1153. The temperature is 68.5

# %%
df.head(500)
# Out:
#              START_DATE            END_DATE  CATEGORY        START     STOP  \
# 0   2016-11-05 19:20:00 2016-11-05 19:28:00  Business        Agnew    Agnew
# 1   2016-11-04 22:12:00 2016-11-04 22:25:00  Business         Cory    Agnew
# 2   2016-11-05 17:29:00 2016-11-05 17:40:00  Business  Renaissance    Agnew
# 3   2016-11-06 16:05:00 2016-11-06 16:22:00  Business  Renaissance    Agnew
# 4   2016-03-17 17:20:00 2016-03-17 18:02:00  Business      Midtown    Alief
# ..                  ...                 ...       ...          ...      ...
# 495 2016-12-28 18:33:00 2016-12-28 18:56:00  Business      Karachi  Karachi
# 496 2016-12-28 22:44:00 2016-12-28 23:18:00  Business      Karachi  Karachi
# 497 2016-12-29 00:49:00 2016-12-29 01:06:00  Business      Karachi  Karachi
# 498 2016-12-29 12:25:00 2016-12-29 12:33:00  Business      Karachi  Karachi
# 499 2016-12-29 13:17:00 2016-12-29 13:24:00  Business      Karachi  Karachi
#
#      MILES          PURPOSE  TEMPERATURE  IS_DAY  RAIN  SNOWFALL  SHOWERS  \
# 0      2.2          NO_DATA         49.3     0.0   0.0       0.0      0.0
# 1      3.9          NO_DATA         41.6     0.0   0.0       0.0      0.0
# 2      2.8          NO_DATA         52.5     0.0   0.0       0.0      0.0
# 3      2.8          Meeting         43.9     1.0   0.0       0.0      0.0
# 4     15.5   Meal/Entertain         50.9     1.0   0.0       0.0      0.0
# ..     ...              ...          ...     ...   ...       ...      ...
# 495    3.8  Errand/Supplies         76.0     0.0   0.0       0.0      0.0
# 496    5.1  Errand/Supplies         72.5     0.0   0.0       0.0      0.0
# 497    3.8  Errand/Supplies         70.0     0.0   0.0       0.0      0.0
# 498    1.4  Errand/Supplies         79.5     1.0   0.0       0.0      0.0
# 499    1.1  Errand/Supplies         80.8     1.0   0.0       0.0      0.0
#
#      WEATHER_CODE  WIND_SPEED_10M  WIND_GUSTS_10M
# 0             1.0             4.0             5.0
# 1             0.0             6.2            13.3
# 2             1.0             7.0            14.8
# 3             0.0            16.3            34.6
# 4             3.0             6.8            28.1
# ..            ...             ...             ...
# 495           0.0            10.2            19.1
# 496           0.0             8.1            11.5
# 497           1.0             8.1            11.2
# 498           0.0             9.4            20.5
# 499           0.0            11.5            23.8
#
# [500 rows x 15 columns]

# %% [markdown]
# 10. Prep the DataFrame so that it would be ready for modeling (don't worry, we won't start modeling just yet!):
#
# a) keep only numeric columns (in a copy)
#
# b) fill in Na values with the group-wise mean for each START location if applicable
#
# c) create these interaction features:
#   - Temperature x Wind Speed (Low temp AND high winds = awful combo, high temp AND high winds = good combo)
#   - Overall Weather Stress (Hint: summation)

# %%
number_cols = df.select_dtypes(include=[np.number]).columns
df_number_only = df[number_cols].copy()

weather_cols = ['TEMPERATURE', 'RAIN', 'WIND_SPEED_10M', 'SNOWFALL', 'SHOWERS', 'WEATHER_CODE', 'WIND_GUSTS_10M']

for col in weather_cols:
  if col in df_number_only.columns:
    # Only fill NaN values in the relevant weather columns
    # Group by 'START' from the original df to get the correct grouping for the mean
    group_mean = df_number_only.groupby(df['START'])[col].transform('mean')
    df_number_only[col] = df_number_only[col].fillna(group_mean)

df_number_only['TEMP_WIND'] = df_number_only['TEMPERATURE'] * df_number_only['WIND_SPEED_10M']
df_number_only['WEATHER_STRESS'] = df_number_only[weather_cols].sum(axis=1)
