# %% [markdown]
# All of the relevant libraries are loaded for your convenience. Load the dataset (and check it!).

# %%
# We will learn:
# 1. What features are
# 2. What the target is
# 3. How to fit a model
# 4. How to make predictions
# 5. How to measure error
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# Load the dataset

# %% [markdown]
# 1. Like before, convert START_DATE into a datetime object. We should also drop 'corrupted' START_DATE rows.

# %%
# TODO Convert START_DATE into a datetime object so we can extract hour and day

# TODO Drop rows where START_DATE could not be converted

# %% [markdown]
# 2. Similar to our forecasting week, our goal here is to bucket our hours for better data points. Use each ride to create bucket hours.

# %%
# TODO Extract the hour of the ride start time

# TODO Extract day of week as a number
# Monday = 0, Tuesday = 1, ..., Sunday = 6

# TODO Create a simple rush hour feature
# We will define rush hour as:
# 7, 8, 9 AM and 4, 5, 6 PM

# TODO Create an hour bucket so that all rides in the same hour are grouped together

print(df[['START_DATE', 'hour', 'day_of_week', 'is_rush_hour', 'hour_bucket']].head())

# Group rides by hour bucket, hour, day_of_week, and rush hour
# Each row in the new table will represent one hour of Uber demand
hourly = ( # TODO
          )

print(hourly.head())
print("Number of hourly rows:", len(hourly))

# %% [markdown]
# 3. Using our new varirable in 2), calculate the average rides per hour of day. Create X and y, where X is the predictors and y is the response.

# %%
# TODO Data Prep: Average rides per hour of day

# TODO Create X and y

# %% [markdown]
# 4. With everything, run sklearn's linear regression prediction model. Our goal here is to try and compare the number of predicted rides per hour of day vs. the actual.
#
# Create a graph with your results and plot it against actual vs. predicted. Draw a regression line.

# %%
# TODO Create Model, fitting, and prediction

# TODO Plot the points, and draw the scatter plot

# TODO Customize your plot (ex: make Title your r^2 value and change your axis labeling)

# %% [markdown]
# 5. Calculate your mean absolute error. Remember, the lower the better!

# %%
# Measure error using mean_absolute_error
