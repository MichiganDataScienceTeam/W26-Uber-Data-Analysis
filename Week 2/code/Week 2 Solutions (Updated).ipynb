# %% [markdown]
# <a href="https://colab.research.google.com/github/MichiganDataScienceTeam/W26-Uber-Data-Analysis/blob/main/Week_2_solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Import the relevant libraries.

# %%
import requests
import re
import pandas as pd
import numpy as np
import os
import json
from datetime import datetime
from urllib.parse import quote

# %% [markdown]
# 2. Load the "corrupted" dataset. Make sure to run methods like .head() and .info() to make sure it was loaded properly!

# %%
df = pd.read_csv(
    "UberDataset [CORRUPTED].csv")

# %% [markdown]
# 3. Iterate through all dataframe columns to check for NaN (empty) cells. If you find one, override the cell with '**NO_DATA**'.

# %%
for col in df.columns:
    df[col] = df[col].fillna("NO_DATA")

# %% [markdown]
# 4. Focus at the START and STOP columns. Scroll around a bit and find the typos. Make a custom pattern that can be used for both typo formats. **OVERRIDE** the previous cell.
#
# The correct words should be: Rawalpindi and Karachi.
#
# Hint: use r'STRING' (raw) for your pattern, and use .findall(pattern, string).

# %%
pattern = r'([A-Z][a-z]*)\?([a-z]*)'
for i in df.index:
  startVal = df.at[i, 'START']
  stopVal = df.at[i, 'STOP']
  if '?' in startVal:
    grouping = re.findall(pattern, startVal)[0]
    firstPart = grouping[0]
    secondPart = grouping[1]
    fixedWord = f'{firstPart}a{secondPart}'
    df.at[i, 'START'] = fixedWord

  if '?' in stopVal:
    grouping = re.findall(pattern, stopVal)[0]
    firstPart = grouping[0]
    secondPart = grouping[1]
    fixedWord = f'{firstPart}a{secondPart}'
    df.at[i, 'STOP'] = fixedWord

df.head(500)
# Out:
#            START_DATE          END_DATE  CATEGORY        START     STOP  \
# 0    11-05-2016 19:20  11-05-2016 19:28  Business        Agnew    Agnew
# 1    11-04-2016 22:12  11-04-2016 22:25  Business         Cory    Agnew
# 2    11-05-2016 17:29  11-05-2016 17:40  Business  Renaissance    Agnew
# 3    11-06-2016 16:05  11-06-2016 16:22  Business  Renaissance    Agnew
# 4     3/17/2016 17:20   3/17/2016 18:02  Business      Midtown    Alief
# ..                ...               ...       ...          ...      ...
# 495  12/28/2016 18:33  12/28/2016 18:56  Business      Karachi  Karachi
# 496  12/28/2016 22:44  12/28/2016 23:18  Business      Karachi  Karachi
# 497   12/29/2016 0:49   12/29/2016 1:06  Business      Karachi  Karachi
# 498  12/29/2016 12:25  12/29/2016 12:33  Business      Karachi  Karachi
# 499  12/29/2016 13:17  12/29/2016 13:24  Business      Karachi  Karachi
#
#      MILES          PURPOSE
# 0      2.2          NO_DATA
# 1      3.9          NO_DATA
# 2      2.8          NO_DATA
# 3      2.8          Meeting
# 4     15.5   Meal/Entertain
# ..     ...              ...
# 495    3.8  Errand/Supplies
# 496    5.1  Errand/Supplies
# 497    3.8  Errand/Supplies
# 498    1.4  Errand/Supplies
# 499    1.1  Errand/Supplies
#
# [500 rows x 7 columns]

# %% [markdown]
# 5. Override all 'Unknown Location' values to 'NO_DATA'

# %%
for i in df.index:
  startVal = df.at[i, 'START']
  stopVal = df.at[i, 'STOP']
  if 'Unknown' in startVal:
    df.at[i, 'START'] = 'NO_DATA'
  if 'Unknown' in stopVal:
    df.at[i, 'STOP'] = 'NO_DATA'
df.tail(500)
# Out:
#             START_DATE          END_DATE  CATEGORY        START  \
# 654   07-03-2016 00:28  07-03-2016 00:38  Business         Cary
# 655   07-06-2016 20:04  07-06-2016 20:14  Business         Cary
# 656   07-07-2016 08:22  07-07-2016 08:50  Business         Cary
# 657    7/13/2016 12:39   7/13/2016 13:20  Personal         Cary
# 658    7/14/2016 15:51   7/14/2016 15:59  Personal         Cary
# ...                ...               ...       ...          ...
# 1149  11-01-2016 19:14  11-01-2016 19:20  Business  Whitebridge
# 1150  11-01-2016 19:59  11-01-2016 20:12  Business  Whitebridge
# 1151  11-01-2016 20:41  11-01-2016 20:55  Business  Whitebridge
# 1152  02-02-2016 13:04  02-02-2016 13:23  Business  Whitebridge
# 1153  10/28/2016 15:53  10/28/2016 17:59  Business         Cary
#
#                     STOP  MILES          PURPOSE
# 654          Morrisville    3.1  Errand/Supplies
# 655          Morrisville    3.3   Meal/Entertain
# 656          Morrisville    7.9   Temporary Site
# 657          Morrisville   23.5          NO_DATA
# 658          Morrisville    3.3          NO_DATA
# ...                  ...    ...              ...
# 1149         Whitebridge    1.0          NO_DATA
# 1150         Whitebridge    4.1          NO_DATA
# 1151         Whitebridge    4.2   Meal/Entertain
# 1152  Williamsburg Manor    8.3          Meeting
# 1153       Winston Salem  107.0          Meeting
#
# [500 rows x 7 columns]

# %% [markdown]
# 6. Convert all the START_DATE and END_DATE values to datetime objects.

# %%
df['START_DATE'] = pd.to_datetime(df['START_DATE'], errors='coerce', format='mixed')
df['END_DATE'] = pd.to_datetime(df['END_DATE'], errors='coerce', format='mixed')

# %% [markdown]
# 7. Create a function that validate that timings for the trip makes sense (start date should be less than end date), and if not, sets both START_DATE and END_DATE to NaT

# %%
def invalid_trip_time(df: pd.DataFrame) -> pd.DataFrame:
  invalid = df["START_DATE"] >= df["END_DATE"]

  df.loc[invalid, "START_DATE"] = pd.NaT
  df.loc[invalid, "END_DATE"] = pd.NaT

  return df

# %% [markdown]
# 8. Extract these specific time features: hour, day of the week, if it is rush hour (let rush hour be between 7-9 am and 4-6 pm), and if it is the weekend (based on START_DATE column)

# %%
df["hour"] = df["START_DATE"].dt.hour
df["day_of_week"] = df["START_DATE"].dt.dayofweek
df["is_weekend"] = df["day_of_week"] > 5
df["is_rush_hour"] = ((df["hour"].between(7,9)) |  (df["hour"].between(16,18)))

# %% [markdown]
# # **Part 2**

# %% [markdown]
# 9. Connect to our **GitHub**. The API data is divided up into hourly segments. Using both the **START** location and the **START_DATE**, as well as the datetime attributes, make a web request for each of your rows.
#
# Hint：Find & get the corresponding index in the hourly list, then use that to get the other attributes.

# %%
# 1. Create a local directory for the cache
cache_dir = 'cached'
if not os.path.exists(cache_dir):
    os.makedirs(cache_dir)

for idx, i in enumerate(df['START']):
    # The local filename where we store the JSON
    cache_file = os.path.join(cache_dir, f"{i}.json")

    # 2. CHECK CACHE: Only make a request if the file isn't local
    if os.path.exists(cache_file):
        with open(cache_file, 'r') as f:
            firstRequest = json.load(f)['hourly']
    else:
        url = f'https://23likenny.github.io/MDSTUber/Week2/{i}.json'
        holder = requests.get(url)

        if holder.status_code == 200:
            full_json = holder.json()
            # SAVE to cache for next time
            with open(cache_file, 'w') as f:
                json.dump(full_json, f)
            firstRequest = full_json['hourly']
        else:
            print(f"Skipping Index {idx}: {i} not found at URL.")
            continue

    x = firstRequest['time']
    currentTime = df.at[idx, 'START_DATE']
    target_str = currentTime.strftime('%Y-%m-%dT%H:00')
    nicer = currentTime.strftime('%A, %B %d, %Y at %I:00 %p')
    find_idx = x.index(target_str)

    # Pulling your variables
    temperature = firstRequest['apparent_temperature'][find_idx]
    is_day = firstRequest['is_day'][find_idx]
    rain = firstRequest['rain'][find_idx]
    snowfall = firstRequest['snowfall'][find_idx]
    showers = firstRequest['showers'][find_idx]
    weather_code = firstRequest['weather_code'][find_idx]
    wind_speed_10m = firstRequest['wind_speed_10m'][find_idx]
    wind_gusts_10m = firstRequest['wind_gusts_10m'][find_idx]
    print(f'The temperature for {i} at {nicer} is {temperature}.')

    # Writing to DataFrame
    df.at[idx, 'TEMPERATURE'] = temperature
    df.at[idx, 'IS_DAY'] = is_day
    df.at[idx, 'RAIN'] = rain
    df.at[idx, 'SNOWFALL'] = snowfall
    df.at[idx, 'SHOWERS'] = showers
    df.at[idx, 'WEATHER_CODE'] = weather_code
    df.at[idx, 'WIND_SPEED_10M'] = wind_speed_10m
    df.at[idx, 'WIND_GUSTS_10M'] = wind_gusts_10m
# Out:
# The temperature for Agnew at Saturday, November 05, 2016 at 07:00 PM is 49.3.
# The temperature for Cory at Friday, November 04, 2016 at 10:00 PM is 41.6.
# The temperature for Renaissance at Saturday, November 05, 2016 at 05:00 PM is 52.5.
# The temperature for Renaissance at Sunday, November 06, 2016 at 04:00 PM is 43.9.
# The temperature for Midtown at Thursday, March 17, 2016 at 05:00 PM is 50.9.
# The temperature for Bryson City at Sunday, October 30, 2016 at 12:00 PM is 75.6.
# The temperature for Apex at Wednesday, August 10, 2016 at 06:00 PM is 91.5.
# The temperature for Apex at Monday, October 17, 2016 at 06:00 PM is 73.5.
# The temperature for Cary at Friday, January 29, 2016 at 06:00 PM is 35.3.
# The temperature for Cary at Saturday, January 30, 2016 at 04:00 PM is 44.0.
# The temperature for Cary at Sunday, February 07, 2016 at 04:00 PM is 30.9.
# The temperature for Cary at Monday, February 29, 2016 at 11:00 AM is 55.2.
# The temperature for Cary at Monday, June 06, 2016 at 08:00 PM is 76.6.
# The temperature for Cary at Monday, July 18, 2016 at 05:00 PM is 96.2.
# The temperature for Cary at Monday, August 01, 2016 at 01:00 PM is 91.8.
# The temperature for Cary at Monday, October 17, 2016 at 06:00 PM is 73.5.
# The temperature for Cary at Tuesday, October 25, 2016 at 01:00 PM is 60.0.
# The temperature for Cary at Saturday, November 19, 2016 at 05:00 PM is 44.3.
# The temperature for Cary at Saturday, November 26, 2016 at 05:00 PM is 43.7.
# The temperature for Cary at Friday, December 02, 2016 at 12:00 PM is 45.1.
# The temperature for Cary at Friday, December 09, 2016 at 12:00 PM is 28.8.
# The temperature for Cary at Monday, December 12, 2016 at 01:00 PM is 51.0.
# The temperature for Durham at Wednesday, August 10, 2016 at 05:00 PM is 52.4.
# The temperature for Chalmette at Saturday, June 25, 2016 at 10:00 AM is 96.3.
# The temperature for Washington at Saturday, August 06, 2016 at 06:00 AM is 83.7.
# The temperature for Whitebridge at Monday, August 01, 2016 at 12:00 PM is 54.3.
# The temperature for South Congress at Thursday, March 10, 2016 at 04:00 PM is 60.1.
# The temperature for Bryson City at Sunday, October 30, 2016 at 01:00 PM is 75.8.
# The temperature for Winston Salem at Friday, October 28, 2016 at 06:00 PM is 63.8.
# The temperature for Banner Elk at Friday, July 15, 2016 at 11:00 AM is 74.2.
# The temperature for Banner Elk at Friday, July 15, 2016 at 12:00 PM is 75.2.
# The temperature for Banner Elk at Friday, July 15, 2016 at 03:00 PM is 81.3.
# The temperature for Banner Elk at Saturday, July 16, 2016 at 09:00 PM is 69.9.
# The temperature for Banner Elk at Saturday, July 16, 2016 at 10:00 PM is 68.7.
# The temperature for Boone at Saturday, July 16, 2016 at 07:00 PM is 72.7.
# The temperature for Elk Park at Friday, July 15, 2016 at 03:00 PM is 83.3.
# The temperature for Morrisville at Thursday, July 14, 2016 at 04:00 PM is 98.7.
# The temperature for Downtown at Tuesday, June 14, 2016 at 05:00 PM is 68.2.
# The temperature for Redmond at Thursday, May 05, 2016 at 10:00 PM is 53.2.
# The temperature for El Cerrito at Wednesday, November 16, 2016 at 10:00 PM is 44.4.
# The temperature for Emeryville at Monday, June 13, 2016 at 06:00 PM is 60.7.
# The temperature for Emeryville at Tuesday, October 18, 2016 at 07:00 PM is 58.3.
# The temperature for Emeryville at Thursday, October 20, 2016 at 11:00 AM is 72.3.
# The temperature for Emeryville at Tuesday, November 08, 2016 at 04:00 PM is 74.2.
# The temperature for Emeryville at Saturday, November 12, 2016 at 03:00 PM is 71.2.
# The temperature for Emeryville at Monday, November 14, 2016 at 08:00 PM is 58.4.
# The temperature for Menlo Park at Friday, November 11, 2016 at 02:00 PM is 72.2.
# The temperature for Mountain View at Monday, November 14, 2016 at 01:00 PM is 71.3.
# The temperature for Oakland at Wednesday, November 09, 2016 at 08:00 PM is 62.7.
# The temperature for Oakland at Thursday, November 10, 2016 at 03:00 PM is 76.0.
# The temperature for San Francisco at Wednesday, October 19, 2016 at 02:00 PM is 68.0.
# The temperature for San Francisco at Monday, November 07, 2016 at 07:00 PM is 63.4.
# The temperature for San Francisco at Tuesday, November 08, 2016 at 12:00 PM is 69.5.
# The temperature for San Francisco at Tuesday, November 15, 2016 at 08:00 PM is 52.1.
# The temperature for Santa Clara at Sunday, November 06, 2016 at 04:00 PM is 68.6.
# The temperature for Banner Elk at Sunday, July 17, 2016 at 11:00 AM is 82.3.
# The temperature for Newland at Saturday, July 16, 2016 at 03:00 PM is 72.4.
# The temperature for Sharpstown at Sunday, March 20, 2016 at 06:00 PM is 29.6.
# The temperature for Almond at Sunday, October 30, 2016 at 12:00 PM is 46.9.
# The temperature for Bryson City at Sunday, October 30, 2016 at 09:00 AM is 68.5.
# The temperature for Bryson City at Sunday, October 30, 2016 at 10:00 AM is 73.5.
# The temperature for Bryson City at Sunday, October 30, 2016 at 10:00 AM is 73.5.
# The temperature for Topton at Sunday, October 30, 2016 at 07:00 AM is 58.6.
# The temperature for Edgehill Farms at Thursday, July 21, 2016 at 05:00 PM is 65.0.
# The temperature for Whitebridge at Wednesday, April 27, 2016 at 01:00 PM is 33.9.
# The temperature for CBD at Saturday, June 25, 2016 at 09:00 AM is 37.4.
# The temperature for Mcvan at Wednesday, May 04, 2016 at 08:00 PM is 51.5.
# The temperature for University District at Wednesday, May 04, 2016 at 10:00 PM is 51.0.
# The temperature for Apex at Friday, January 29, 2016 at 09:00 PM is 30.2.
# The temperature for Apex at Saturday, January 30, 2016 at 06:00 PM is 39.4.
# The temperature for Apex at Sunday, February 07, 2016 at 06:00 PM is 30.0.
# The temperature for Apex at Monday, February 29, 2016 at 12:00 PM is 58.6.
# The temperature for Apex at Monday, June 06, 2016 at 09:00 PM is 75.4.
# The temperature for Apex at Monday, July 18, 2016 at 06:00 PM is 95.6.
# The temperature for Apex at Monday, August 01, 2016 at 03:00 PM is 92.4.
# The temperature for Apex at Wednesday, August 10, 2016 at 07:00 PM is 89.8.
# The temperature for Apex at Monday, October 17, 2016 at 07:00 PM is 70.9.
# The temperature for Apex at Saturday, November 19, 2016 at 09:00 PM is 34.9.
# The temperature for Apex at Friday, December 02, 2016 at 01:00 PM is 46.5.
# The temperature for Apex at Friday, December 09, 2016 at 01:00 PM is 30.3.
# The temperature for Apex at Monday, December 12, 2016 at 02:00 PM is 52.5.
# The temperature for Boone at Sunday, July 17, 2016 at 12:00 PM is 78.9.
# The temperature for Cary at Thursday, January 07, 2016 at 01:00 PM is 48.2.
# The temperature for Cary at Monday, January 18, 2016 at 02:00 PM is 24.4.
# The temperature for Cary at Thursday, January 21, 2016 at 02:00 PM is 33.7.
# The temperature for Cary at Thursday, January 21, 2016 at 02:00 PM is 33.7.
# The temperature for Cary at Thursday, January 21, 2016 at 04:00 PM is 33.4.
# The temperature for Cary at Tuesday, January 26, 2016 at 05:00 PM is 51.2.
# The temperature for Cary at Tuesday, January 26, 2016 at 05:00 PM is 51.2.
# The temperature for Cary at Wednesday, January 27, 2016 at 09:00 AM is 34.5.
# The temperature for Cary at Friday, January 29, 2016 at 09:00 AM is 32.8.
# The temperature for Cary at Friday, January 29, 2016 at 10:00 AM is 36.2.
# The temperature for Cary at Tuesday, February 02, 2016 at 01:00 PM is 54.3.
# The temperature for Cary at Tuesday, February 02, 2016 at 02:00 PM is 52.0.
# The temperature for Cary at Thursday, February 04, 2016 at 10:00 AM is 46.3.
# The temperature for Cary at Thursday, February 04, 2016 at 03:00 PM is 50.1.
# The temperature for Cary at Thursday, February 04, 2016 at 04:00 PM is 49.6.
# The temperature for Cary at Thursday, February 04, 2016 at 08:00 PM is 44.0.
# The temperature for Cary at Saturday, November 19, 2016 at 04:00 PM is 48.3.
# The temperature for Cary at Saturday, November 19, 2016 at 04:00 PM is 48.3.
# The temperature for Cary at Sunday, November 20, 2016 at 10:00 AM is 32.1.
# The temperature for Cary at Sunday, November 20, 2016 at 11:00 AM is 33.8.
# The temperature for Cary at Sunday, November 20, 2016 at 02:00 PM is 38.6.
# The temperature for Cary at Sunday, November 20, 2016 at 05:00 PM is 38.0.
# The temperature for Cary at Monday, November 21, 2016 at 01:00 PM is 39.4.
# The temperature for Cary at Monday, November 21, 2016 at 02:00 PM is 41.7.
# The temperature for Cary at Tuesday, November 22, 2016 at 03:00 PM is 45.6.
# The temperature for Cary at Tuesday, November 22, 2016 at 03:00 PM is 45.6.
# The temperature for Cary at Tuesday, November 22, 2016 at 03:00 PM is 45.6.
# The temperature for Cary at Wednesday, November 23, 2016 at 03:00 PM is 48.8.
# The temperature for Cary at Wednesday, November 23, 2016 at 04:00 PM is 47.6.
# The temperature for Cary at Wednesday, November 23, 2016 at 04:00 PM is 47.6.
# The temperature for Cary at Wednesday, November 23, 2016 at 06:00 PM is 40.9.
# The temperature for Cary at Saturday, November 26, 2016 at 03:00 PM is 45.7.
# The temperature for Cary at Saturday, November 26, 2016 at 07:00 PM is 38.9.
# The temperature for Cary at Thursday, December 01, 2016 at 07:00 AM is 51.6.
# The temperature for Cary at Thursday, December 01, 2016 at 08:00 AM is 50.2.
# The temperature for Cary at Monday, December 05, 2016 at 06:00 PM is 47.6.
# The temperature for Cary at Monday, December 05, 2016 at 07:00 PM is 47.0.
# The temperature for Cary at Wednesday, December 07, 2016 at 12:00 PM is 49.2.
# The temperature for Cary at Wednesday, December 07, 2016 at 12:00 PM is 49.2.
# The temperature for Cary at Wednesday, December 07, 2016 at 07:00 PM is 44.0.
# The temperature for Cary at Wednesday, December 07, 2016 at 09:00 PM is 41.2.
# The temperature for Cary at Thursday, December 08, 2016 at 02:00 PM is 41.9.
# The temperature for Cary at Thursday, December 08, 2016 at 02:00 PM is 41.9.
# The temperature for Cary at Thursday, December 08, 2016 at 07:00 PM is 35.0.
# The temperature for Cary at Thursday, December 08, 2016 at 09:00 PM is 32.3.
# The temperature for Cary at Friday, December 09, 2016 at 08:00 PM is 24.6.
# The temperature for Cary at Friday, December 09, 2016 at 10:00 PM is 22.7.
# The temperature for Cary at Sunday, December 11, 2016 at 09:00 PM is 33.7.
# The temperature for Cary at Monday, December 12, 2016 at 01:00 PM is 51.0.
# The temperature for Cary at Tuesday, December 13, 2016 at 06:00 PM is 46.0.
# The temperature for Cary at Tuesday, December 13, 2016 at 08:00 PM is 45.6.
# The temperature for Cary at Wednesday, December 14, 2016 at 04:00 PM is 45.1.
# The temperature for Cary at Wednesday, December 14, 2016 at 05:00 PM is 44.4.
# The temperature for Chapel Hill at Monday, February 01, 2016 at 12:00 PM is 59.6.
# The temperature for Durham at Friday, January 15, 2016 at 01:00 PM is 23.6.
# The temperature for Durham at Friday, January 29, 2016 at 01:00 PM is 30.4.
# The temperature for Durham at Friday, February 05, 2016 at 01:00 PM is 37.9.
# The temperature for Durham at Friday, February 26, 2016 at 01:00 PM is 32.0.
# The temperature for Durham at Friday, March 04, 2016 at 09:00 AM is 26.5.
# The temperature for Durham at Friday, March 04, 2016 at 01:00 PM is 29.1.
# The temperature for Durham at Friday, April 08, 2016 at 01:00 PM is 43.0.
# The temperature for Durham at Friday, April 22, 2016 at 01:00 PM is 38.4.
# The temperature for Durham at Friday, April 29, 2016 at 01:00 PM is 33.9.
# The temperature for Durham at Friday, April 29, 2016 at 10:00 PM is 29.4.
# The temperature for Durham at Friday, June 03, 2016 at 01:00 PM is 55.7.
# The temperature for Durham at Sunday, June 05, 2016 at 11:00 PM is 46.9.
# The temperature for Durham at Monday, June 06, 2016 at 11:00 PM is 53.7.
# The temperature for Durham at Tuesday, June 07, 2016 at 11:00 PM is 59.2.
# The temperature for Durham at Friday, June 10, 2016 at 11:00 PM is 50.5.
# The temperature for Durham at Saturday, June 11, 2016 at 11:00 PM is 49.9.
# The temperature for Durham at Tuesday, June 28, 2016 at 11:00 PM is 47.9.
# The temperature for Durham at Tuesday, June 28, 2016 at 11:00 PM is 47.9.
# The temperature for Durham at Wednesday, June 29, 2016 at 11:00 PM is 44.6.
# The temperature for Durham at Friday, July 01, 2016 at 12:00 AM is 49.4.
# The temperature for Durham at Friday, July 01, 2016 at 11:00 PM is 41.5.
# The temperature for Durham at Saturday, July 02, 2016 at 11:00 PM is 43.9.
# The temperature for Durham at Monday, July 04, 2016 at 12:00 AM is 45.2.
# The temperature for Durham at Tuesday, July 05, 2016 at 12:00 AM is 54.7.
# The temperature for Durham at Wednesday, July 06, 2016 at 12:00 PM is 55.8.
# The temperature for Durham at Friday, July 22, 2016 at 01:00 PM is 68.9.
# The temperature for Durham at Saturday, July 23, 2016 at 11:00 PM is 58.3.
# The temperature for Durham at Saturday, July 30, 2016 at 09:00 PM is 52.0.
# The temperature for Durham at Friday, October 28, 2016 at 01:00 PM is 46.0.
# The temperature for Durham at Tuesday, November 01, 2016 at 04:00 PM is 39.5.
# The temperature for Durham at Saturday, November 19, 2016 at 02:00 PM is 31.7.
# The temperature for Durham at Friday, November 25, 2016 at 01:00 PM is 32.9.
# The temperature for Eagle Rock at Tuesday, October 25, 2016 at 03:00 PM is 75.8.
# The temperature for Florence at Sunday, April 03, 2016 at 02:00 AM is 47.1.
# The temperature for Fuquay-Varina at Saturday, December 10, 2016 at 02:00 PM is 32.4.
# The temperature for Holly Springs at Thursday, April 14, 2016 at 04:00 PM is 55.9.
# The temperature for Holly Springs at Saturday, November 26, 2016 at 06:00 PM is 41.4.
# The temperature for Mebane at Sunday, October 30, 2016 at 06:00 PM is 69.5.
# The temperature for Morrisville at Friday, January 15, 2016 at 12:00 AM is 33.7.
# The temperature for Morrisville at Thursday, February 04, 2016 at 09:00 AM is 53.6.
# The temperature for Morrisville at Sunday, February 07, 2016 at 08:00 PM is 29.6.
# The temperature for Morrisville at Tuesday, February 09, 2016 at 08:00 PM is 26.0.
# The temperature for Morrisville at Thursday, February 11, 2016 at 08:00 PM is 24.0.
# The temperature for Morrisville at Friday, February 12, 2016 at 03:00 PM is 25.0.
# The temperature for Morrisville at Monday, February 22, 2016 at 09:00 PM is 43.6.
# The temperature for Morrisville at Friday, March 04, 2016 at 07:00 PM is 43.3.
# The temperature for Morrisville at Saturday, March 05, 2016 at 02:00 PM is 45.1.
# The temperature for Morrisville at Saturday, March 05, 2016 at 05:00 PM is 45.6.
# The temperature for Morrisville at Tuesday, March 22, 2016 at 12:00 PM is 55.3.
# The temperature for Morrisville at Thursday, April 07, 2016 at 07:00 PM is 53.6.
# The temperature for Morrisville at Tuesday, April 12, 2016 at 01:00 PM is 61.3.
# The temperature for Morrisville at Saturday, April 16, 2016 at 03:00 PM is 62.4.
# The temperature for Morrisville at Sunday, April 24, 2016 at 09:00 PM is 57.1.
# The temperature for Morrisville at Thursday, April 28, 2016 at 10:00 PM is 71.9.
# The temperature for Morrisville at Tuesday, May 03, 2016 at 10:00 PM is 67.1.
# The temperature for Morrisville at Friday, May 06, 2016 at 05:00 PM is 60.4.
# The temperature for Morrisville at Wednesday, May 11, 2016 at 09:00 PM is 75.1.
# The temperature for Morrisville at Saturday, May 14, 2016 at 11:00 PM is 51.5.
# The temperature for Morrisville at Friday, May 20, 2016 at 03:00 PM is 66.4.
# The temperature for Morrisville at Sunday, May 22, 2016 at 06:00 PM is 63.1.
# The temperature for Morrisville at Saturday, May 28, 2016 at 02:00 PM is 86.8.
# The temperature for Morrisville at Wednesday, June 01, 2016 at 01:00 PM is 88.8.
# The temperature for Morrisville at Friday, June 03, 2016 at 06:00 PM is 87.9.
# The temperature for Morrisville at Friday, June 03, 2016 at 10:00 PM is 83.6.
# The temperature for Morrisville at Sunday, June 05, 2016 at 06:00 PM is 84.0.
# The temperature for Morrisville at Saturday, June 11, 2016 at 05:00 PM is 94.2.
# The temperature for Morrisville at Sunday, June 12, 2016 at 08:00 PM is 85.0.
# The temperature for Morrisville at Saturday, June 18, 2016 at 12:00 AM is 65.9.
# The temperature for Morrisville at Friday, June 24, 2016 at 01:00 PM is 95.1.
# The temperature for Morrisville at Tuesday, June 28, 2016 at 12:00 AM is 80.1.
# The temperature for Morrisville at Wednesday, June 29, 2016 at 10:00 AM is 89.8.
# The temperature for Morrisville at Sunday, July 03, 2016 at 03:00 AM is 80.8.
# The temperature for Morrisville at Wednesday, July 06, 2016 at 12:00 AM is 85.1.
# The temperature for Morrisville at Wednesday, July 06, 2016 at 11:00 PM is 85.1.
# The temperature for Morrisville at Thursday, July 07, 2016 at 10:00 AM is 95.0.
# The temperature for Morrisville at Tuesday, July 12, 2016 at 11:00 PM is 83.5.
# The temperature for Morrisville at Wednesday, July 13, 2016 at 01:00 PM is 98.0.
# The temperature for Morrisville at Monday, July 18, 2016 at 10:00 AM is 90.8.
# The temperature for Morrisville at Monday, July 18, 2016 at 09:00 PM is 90.1.
# The temperature for Morrisville at Thursday, July 21, 2016 at 07:00 PM is 87.5.
# The temperature for Morrisville at Friday, July 22, 2016 at 11:00 AM is 96.4.
# The temperature for Morrisville at Friday, July 22, 2016 at 03:00 PM is 98.0.
# The temperature for Morrisville at Saturday, July 23, 2016 at 02:00 PM is 103.5.
# The temperature for Morrisville at Saturday, July 23, 2016 at 03:00 PM is 102.4.
# The temperature for Morrisville at Monday, July 25, 2016 at 11:00 AM is 101.0.
# The temperature for Morrisville at Tuesday, July 26, 2016 at 10:00 PM is 91.9.
# The temperature for Morrisville at Thursday, July 28, 2016 at 12:00 AM is 91.9.
# The temperature for Morrisville at Monday, August 01, 2016 at 05:00 PM is 94.9.
# The temperature for Morrisville at Saturday, August 06, 2016 at 09:00 AM is 85.8.
# The temperature for Morrisville at Sunday, August 07, 2016 at 08:00 PM is 88.8.
# The temperature for Morrisville at Monday, August 08, 2016 at 11:00 PM is 82.0.
# The temperature for Morrisville at Sunday, October 16, 2016 at 12:00 AM is 57.3.
# The temperature for Morrisville at Sunday, October 16, 2016 at 03:00 PM is 75.9.
# The temperature for Morrisville at Sunday, October 16, 2016 at 09:00 PM is 64.5.
# The temperature for Morrisville at Saturday, October 22, 2016 at 12:00 AM is 46.8.
# The temperature for Morrisville at Sunday, October 23, 2016 at 09:00 PM is 52.2.
# The temperature for Morrisville at Monday, October 24, 2016 at 04:00 PM is 73.1.
# The temperature for Morrisville at Thursday, October 27, 2016 at 09:00 PM is 64.7.
# The temperature for Morrisville at Wednesday, November 02, 2016 at 05:00 PM is 77.2.
# The temperature for Morrisville at Thursday, November 03, 2016 at 10:00 PM is 66.6.
# The temperature for Morrisville at Friday, November 18, 2016 at 09:00 PM is 55.0.
# The temperature for Morrisville at Monday, November 21, 2016 at 06:00 PM is 37.7.
# The temperature for Morrisville at Tuesday, November 22, 2016 at 09:00 PM is 40.5.
# The temperature for Morrisville at Sunday, November 27, 2016 at 06:00 PM is 41.0.
# The temperature for Morrisville at Wednesday, November 30, 2016 at 12:00 PM is 71.3.
# The temperature for Morrisville at Thursday, December 01, 2016 at 08:00 PM is 47.2.
# The temperature for Morrisville at Friday, December 02, 2016 at 10:00 PM is 38.7.
# The temperature for Morrisville at Saturday, December 03, 2016 at 08:00 PM is 40.5.
# The temperature for Morrisville at Sunday, December 04, 2016 at 08:00 PM is 37.7.
# The temperature for Morrisville at Saturday, December 10, 2016 at 10:00 PM is 21.7.
# The temperature for Morrisville at Sunday, December 11, 2016 at 07:00 PM is 33.0.
# The temperature for Morrisville at Monday, December 12, 2016 at 08:00 PM is 46.3.
# The temperature for Morrisville at Wednesday, December 14, 2016 at 08:00 PM is 38.9.
# The temperature for Raleigh at Wednesday, January 20, 2016 at 01:00 PM is 25.2.
# The temperature for Raleigh at Wednesday, January 27, 2016 at 02:00 PM is 42.6.
# The temperature for Raleigh at Thursday, January 28, 2016 at 04:00 PM is 41.1.
# The temperature for Raleigh at Saturday, February 06, 2016 at 06:00 PM is 35.6.
# The temperature for Raleigh at Friday, February 12, 2016 at 01:00 PM is 24.4.
# The temperature for Raleigh at Thursday, March 03, 2016 at 04:00 PM is 41.0.
# The temperature for Raleigh at Friday, March 04, 2016 at 04:00 PM is 42.7.
# The temperature for Raleigh at Monday, March 07, 2016 at 03:00 PM is 57.1.
# The temperature for Raleigh at Friday, April 08, 2016 at 04:00 PM is 52.5.
# The temperature for Raleigh at Friday, April 15, 2016 at 02:00 PM is 57.0.
# The temperature for Raleigh at Friday, April 22, 2016 at 10:00 AM is 68.4.
# The temperature for Raleigh at Thursday, April 28, 2016 at 01:00 PM is 88.4.
# The temperature for Raleigh at Tuesday, May 31, 2016 at 04:00 PM is 86.1.
# The temperature for Raleigh at Sunday, June 19, 2016 at 05:00 AM is 58.6.
# The temperature for Raleigh at Tuesday, June 21, 2016 at 05:00 PM is 89.7.
# The temperature for Raleigh at Friday, July 01, 2016 at 12:00 PM is 92.0.
# The temperature for Raleigh at Tuesday, August 09, 2016 at 04:00 PM is 92.3.
# The temperature for Raleigh at Monday, October 17, 2016 at 04:00 PM is 79.5.
# The temperature for Raleigh at Saturday, October 22, 2016 at 05:00 PM is 51.3.
# The temperature for Raleigh at Sunday, October 23, 2016 at 12:00 PM is 60.4.
# The temperature for Raleigh at Monday, October 31, 2016 at 08:00 PM is 58.8.
# The temperature for Wake Forest at Thursday, August 11, 2016 at 08:00 PM is 88.8.
# The temperature for Pontchartrain Beach at Friday, July 08, 2016 at 10:00 AM is 97.6.
# The temperature for St Thomas at Sunday, July 10, 2016 at 04:00 PM is 86.1.
# The temperature for Meredith at Tuesday, April 12, 2016 at 10:00 AM is 44.4.
# The temperature for Central at Wednesday, November 09, 2016 at 09:00 PM is 82.5.
# The temperature for Central at Sunday, November 13, 2016 at 08:00 AM is 85.5.
# The temperature for Central at Sunday, November 13, 2016 at 09:00 AM is 86.2.
# The temperature for College Avenue at Friday, November 11, 2016 at 09:00 PM is 35.5.
# The temperature for Downtown at Saturday, November 12, 2016 at 01:00 PM is 74.6.
# The temperature for Southside at Sunday, November 13, 2016 at 02:00 PM is 41.2.
# The temperature for Southside at Sunday, November 13, 2016 at 03:00 PM is 41.7.
# The temperature for West Berkeley at Sunday, November 06, 2016 at 08:00 PM is 59.7.
# The temperature for West Berkeley at Thursday, November 10, 2016 at 07:00 PM is 66.4.
# The temperature for New Orleans at Saturday, June 25, 2016 at 09:00 AM is 94.1.
# The temperature for Cary at Monday, February 01, 2016 at 10:00 AM is 51.6.
# The temperature for Chessington at Sunday, April 24, 2016 at 07:00 PM is 39.8.
# The temperature for Whitebridge at Tuesday, July 19, 2016 at 05:00 PM is 75.4.
# The temperature for Central at Friday, November 11, 2016 at 06:00 PM is 85.5.
# The temperature for Colombo at Tuesday, February 16, 2016 at 10:00 AM is 94.9.
# The temperature for Colombo at Tuesday, February 16, 2016 at 11:00 AM is 97.2.
# The temperature for Colombo at Tuesday, February 16, 2016 at 12:00 PM is 94.2.
# The temperature for Colombo at Tuesday, February 16, 2016 at 01:00 PM is 93.8.
# The temperature for Colombo at Tuesday, February 16, 2016 at 04:00 PM is 90.3.
# The temperature for Colombo at Wednesday, February 17, 2016 at 03:00 PM is 95.4.
# Skipping Index 294: NO_DATA not found at URL.
# Skipping Index 295: NO_DATA not found at URL.
# Skipping Index 296: Kalorama Triangle not found at URL.
# The temperature for The Drag at Friday, March 11, 2016 at 09:00 AM is 62.2.
# The temperature for The Drag at Wednesday, March 16, 2016 at 11:00 AM is 70.7.
# The temperature for West University at Wednesday, March 16, 2016 at 06:00 PM is 70.8.
# The temperature for The Drag at Sunday, March 13, 2016 at 09:00 AM is 64.2.
# The temperature for The Drag at Tuesday, March 15, 2016 at 08:00 AM is 66.2.
# The temperature for Agnew at Friday, November 04, 2016 at 09:00 PM is 46.4.
# The temperature for Covington at Monday, June 27, 2016 at 08:00 AM is 84.3.
# The temperature for Covington at Monday, June 27, 2016 at 09:00 AM is 86.8.
# The temperature for Covington at Monday, June 27, 2016 at 09:00 AM is 86.8.
# The temperature for Covington at Monday, June 27, 2016 at 10:00 AM is 88.1.
# The temperature for Covington at Monday, June 27, 2016 at 10:00 AM is 88.1.
# The temperature for New Orleans at Monday, June 27, 2016 at 07:00 AM is 95.1.
# The temperature for North Austin at Sunday, March 13, 2016 at 09:00 PM is 69.2.
# The temperature for Kissimmee at Saturday, April 02, 2016 at 12:00 PM is 88.6.
# The temperature for Fayetteville Street at Friday, March 04, 2016 at 04:00 PM is 43.3.
# The temperature for Congress Ave District at Friday, March 11, 2016 at 10:00 AM is 64.7.
# The temperature for Gulfton at Wednesday, January 13, 2016 at 03:00 PM is 59.5.
# Skipping Index 314: Kalorama Triangle not found at URL.
# The temperature for Midtown at Monday, March 21, 2016 at 10:00 AM is 33.6.
# The temperature for NOMA at Wednesday, November 09, 2016 at 03:00 PM is 10.4.
# The temperature for Red River District at Friday, March 11, 2016 at 01:00 PM is 49.3.
# The temperature for South at Saturday, November 12, 2016 at 10:00 AM is 93.1.
# The temperature for Cary at Friday, January 15, 2016 at 11:00 AM is 39.7.
# The temperature for Cary at Friday, January 29, 2016 at 11:00 AM is 38.1.
# The temperature for Cary at Friday, February 05, 2016 at 11:00 AM is 29.8.
# The temperature for Cary at Friday, February 12, 2016 at 08:00 AM is 17.7.
# The temperature for Cary at Friday, February 26, 2016 at 11:00 AM is 34.6.
# The temperature for Cary at Friday, March 04, 2016 at 07:00 AM is 27.5.
# The temperature for Cary at Friday, March 04, 2016 at 11:00 AM is 32.8.
# The temperature for Cary at Friday, April 08, 2016 at 12:00 PM is 53.2.
# The temperature for Cary at Friday, April 22, 2016 at 12:00 PM is 68.3.
# The temperature for Cary at Friday, April 29, 2016 at 11:00 AM is 68.5.
# The temperature for Cary at Friday, April 29, 2016 at 06:00 PM is 72.5.
# The temperature for Cary at Friday, June 03, 2016 at 11:00 AM is 92.9.
# The temperature for Cary at Sunday, June 05, 2016 at 09:00 PM is 78.9.
# The temperature for Cary at Monday, June 06, 2016 at 09:00 PM is 75.7.
# The temperature for Cary at Tuesday, June 07, 2016 at 09:00 PM is 73.8.
# The temperature for Cary at Friday, June 10, 2016 at 09:00 PM is 69.8.
# The temperature for Cary at Saturday, June 11, 2016 at 09:00 PM is 83.7.
# The temperature for Cary at Tuesday, June 28, 2016 at 08:00 PM is 80.2.
# The temperature for Cary at Wednesday, June 29, 2016 at 08:00 PM is 83.8.
# The temperature for Cary at Thursday, June 30, 2016 at 08:00 PM is 86.3.
# The temperature for Cary at Friday, July 01, 2016 at 08:00 PM is 88.2.
# The temperature for Cary at Saturday, July 02, 2016 at 08:00 PM is 83.6.
# The temperature for Cary at Sunday, July 03, 2016 at 08:00 PM is 78.2.
# The temperature for Cary at Monday, July 04, 2016 at 08:00 PM is 84.8.
# The temperature for Cary at Tuesday, July 05, 2016 at 08:00 PM is 88.3.
# The temperature for Cary at Wednesday, July 06, 2016 at 09:00 AM is 90.0.
# The temperature for Cary at Friday, July 22, 2016 at 12:00 PM is 95.0.
# The temperature for Cary at Saturday, July 23, 2016 at 08:00 PM is 90.8.
# The temperature for Cary at Saturday, July 30, 2016 at 05:00 PM is 92.2.
# The temperature for Cary at Wednesday, August 10, 2016 at 04:00 PM is 92.2.
# The temperature for Cary at Sunday, October 16, 2016 at 12:00 PM is 74.2.
# The temperature for Cary at Monday, October 24, 2016 at 02:00 PM is 72.6.
# The temperature for Cary at Friday, October 28, 2016 at 11:00 AM is 61.2.
# The temperature for Cary at Tuesday, November 01, 2016 at 11:00 AM is 59.5.
# The temperature for Cary at Saturday, November 19, 2016 at 01:00 PM is 66.4.
# The temperature for Cary at Friday, November 25, 2016 at 11:00 AM is 62.1.
# The temperature for Apex at Tuesday, October 25, 2016 at 03:00 PM is 60.5.
# The temperature for Jackson Heights at Sunday, February 14, 2016 at 12:00 AM is -10.4.
# The temperature for Midtown at Sunday, January 10, 2016 at 07:00 PM is 40.2.
# The temperature for Farmington Woods at Monday, August 08, 2016 at 04:00 PM is 92.0.
# The temperature for Heritage Pines at Thursday, August 11, 2016 at 01:00 PM is 98.2.
# The temperature for Whitebridge at Monday, February 08, 2016 at 12:00 PM is 30.0.
# The temperature for Whitebridge at Monday, March 07, 2016 at 09:00 AM is 26.2.
# The temperature for Whitebridge at Tuesday, April 12, 2016 at 09:00 AM is 35.2.
# The temperature for Whitebridge at Wednesday, July 20, 2016 at 05:00 PM is 64.8.
# The temperature for Whitebridge at Thursday, July 21, 2016 at 05:00 PM is 64.0.
# The temperature for Whitebridge at Monday, August 01, 2016 at 04:00 PM is 56.1.
# The temperature for Whitebridge at Sunday, August 07, 2016 at 05:00 PM is 47.8.
# The temperature for Whitebridge at Tuesday, October 18, 2016 at 08:00 AM is 34.8.
# The temperature for Berkeley at Wednesday, November 16, 2016 at 08:00 PM is 45.6.
# The temperature for Banner Elk at Friday, July 15, 2016 at 12:00 PM is 75.2.
# The temperature for Berkeley at Tuesday, October 18, 2016 at 08:00 PM is 55.9.
# The temperature for Berkeley at Wednesday, October 19, 2016 at 04:00 PM is 69.2.
# The temperature for Berkeley at Tuesday, November 08, 2016 at 01:00 PM is 72.9.
# The temperature for Berkeley at Saturday, November 12, 2016 at 03:00 PM is 70.5.
# The temperature for Berkeley at Monday, November 14, 2016 at 03:00 PM is 68.5.
# The temperature for Oakland at Monday, June 13, 2016 at 02:00 PM is 68.8.
# The temperature for Oakland at Tuesday, October 18, 2016 at 06:00 PM is 60.8.
# The temperature for San Francisco at Tuesday, June 14, 2016 at 04:00 PM is 57.3.
# The temperature for San Jose at Thursday, October 20, 2016 at 08:00 PM is 63.5.
# The temperature for Whitebridge at Monday, August 08, 2016 at 04:00 PM is 46.3.
# The temperature for Storyville at Wednesday, June 15, 2016 at 07:00 PM is 92.5.
# The temperature for Tribeca at Wednesday, June 08, 2016 at 05:00 PM is 55.0.
# The temperature for Ridgeland at Saturday, April 02, 2016 at 11:00 PM is 43.9.
# The temperature for Fort Pierce at Friday, January 01, 2016 at 09:00 PM is 80.0.
# The temperature for Fort Pierce at Saturday, January 02, 2016 at 01:00 AM is 75.5.
# The temperature for Fort Pierce at Saturday, January 02, 2016 at 08:00 PM is 71.8.
# The temperature for Fort Pierce at Tuesday, January 05, 2016 at 05:00 PM is 61.3.
# Skipping Index 387: SOMISSPO not found at URL.
# The temperature for Cary at Saturday, December 10, 2016 at 12:00 PM is 30.0.
# The temperature for Houston at Saturday, March 19, 2016 at 03:00 PM is 58.2.
# The temperature for Port Bolivar at Saturday, March 19, 2016 at 06:00 PM is 58.7.
# The temperature for Katunayake at Saturday, December 31, 2016 at 09:00 PM is 82.5.
# The temperature for Seaport at Wednesday, June 08, 2016 at 01:00 PM is 70.0.
# The temperature for Midtown at Tuesday, March 22, 2016 at 06:00 AM is 21.1.
# The temperature for Downtown at Wednesday, January 13, 2016 at 01:00 PM is 56.9.
# The temperature for Meredith Townes at Friday, April 15, 2016 at 12:00 PM is 55.4.
# The temperature for Topton at Saturday, October 29, 2016 at 03:00 PM is 62.7.
# The temperature for Westpark Place at Friday, February 26, 2016 at 03:00 PM is 41.2.
# The temperature for Whitebridge at Tuesday, January 26, 2016 at 10:00 AM is 35.9.
# The temperature for Whitebridge at Monday, February 29, 2016 at 02:00 PM is 29.6.
# The temperature for Whitebridge at Monday, June 06, 2016 at 03:00 PM is 73.8.
# The temperature for Whitebridge at Thursday, November 03, 2016 at 11:00 AM is 38.0.
# The temperature for Hudson Square at Tuesday, January 12, 2016 at 03:00 PM is 89.0.
# The temperature for Whitebridge at Thursday, February 25, 2016 at 04:00 PM is 28.1.
# The temperature for Whitebridge at Thursday, August 11, 2016 at 12:00 PM is 55.0.
# The temperature for Old City at Friday, May 20, 2016 at 10:00 AM is 49.9.
# The temperature for Apex at Saturday, November 26, 2016 at 05:00 PM is 44.1.
# The temperature for Cary at Thursday, April 14, 2016 at 07:00 AM is 37.2.
# The temperature for Galveston at Saturday, March 19, 2016 at 07:00 PM is 57.1.
# The temperature for Houston at Thursday, January 14, 2016 at 04:00 PM is 67.1.
# The temperature for Houston at Thursday, March 17, 2016 at 06:00 PM is 76.6.
# The temperature for Houston at Thursday, March 17, 2016 at 08:00 PM is 73.7.
# The temperature for Katy at Thursday, March 17, 2016 at 03:00 PM is 80.5.
# The temperature for Sugar Land at Saturday, March 19, 2016 at 02:00 PM is 58.7.
# The temperature for Lower Manhattan at Tuesday, January 12, 2016 at 02:00 PM is 31.7.
# The temperature for Midtown at Tuesday, January 12, 2016 at 12:00 PM is 27.2.
# The temperature for Huntington Woods at Thursday, October 27, 2016 at 07:00 PM is 37.5.
# The temperature for Gampaha at Saturday, December 31, 2016 at 10:00 PM is 81.7.
# The temperature for Sunnyside at Wednesday, November 09, 2016 at 06:00 PM is 51.9.
# The temperature for Islamabad at Friday, February 19, 2016 at 11:00 AM is 64.3.
# The temperature for Islamabad at Friday, February 19, 2016 at 11:00 AM is 64.3.
# The temperature for Islamabad at Friday, February 19, 2016 at 05:00 PM is 56.1.
# The temperature for Islamabad at Saturday, February 20, 2016 at 10:00 AM is 60.3.
# The temperature for Islamabad at Saturday, February 20, 2016 at 11:00 AM is 63.7.
# The temperature for Islamabad at Sunday, February 21, 2016 at 11:00 AM is 66.2.
# The temperature for Islamabad at Tuesday, August 16, 2016 at 10:00 AM is 95.5.
# The temperature for Islamabad at Friday, August 19, 2016 at 03:00 PM is 101.3.
# The temperature for Islamabad at Sunday, August 21, 2016 at 06:00 PM is 96.6.
# The temperature for Islamabad at Monday, August 22, 2016 at 01:00 PM is 102.6.
# The temperature for Islamabad at Sunday, August 28, 2016 at 05:00 PM is 89.6.
# The temperature for Islamabad at Monday, August 29, 2016 at 01:00 PM is 99.8.
# The temperature for Islamabad at Monday, August 29, 2016 at 02:00 PM is 99.1.
# The temperature for Islamabad at Monday, August 29, 2016 at 06:00 PM is 92.8.
# The temperature for Islamabad at Tuesday, August 30, 2016 at 01:00 PM is 96.7.
# The temperature for Islamabad at Friday, September 30, 2016 at 05:00 PM is 93.3.
# The temperature for Islamabad at Monday, October 03, 2016 at 06:00 PM is 89.1.
# The temperature for Islamabad at Monday, October 03, 2016 at 06:00 PM is 89.1.
# The temperature for Islamabad at Monday, October 10, 2016 at 05:00 PM is 81.9.
# The temperature for Islamabad at Thursday, October 13, 2016 at 12:00 PM is 87.6.
# The temperature for Islamabad at Thursday, October 13, 2016 at 01:00 PM is 87.7.
# The temperature for Islamabad at Thursday, October 13, 2016 at 01:00 PM is 87.7.
# The temperature for Islamabad at Tuesday, December 20, 2016 at 04:00 PM is 64.6.
# The temperature for Islamabad at Tuesday, December 20, 2016 at 04:00 PM is 64.6.
# The temperature for Islamabad at Wednesday, December 21, 2016 at 05:00 PM is 61.9.
# Skipping Index 444: Noorpur Shahan not found at URL.
# Skipping Index 445: Noorpur Shahan not found at URL.
# Skipping Index 446: Noorpur Shahan not found at URL.
# The temperature for Rawalpindi at Wednesday, August 17, 2016 at 03:00 PM is 99.6.
# The temperature for Rawalpindi at Monday, December 19, 2016 at 04:00 PM is 63.2.
# Skipping Index 449: NO_DATA not found at URL.
# Skipping Index 450: NO_DATA not found at URL.
# Skipping Index 451: NO_DATA not found at URL.
# Skipping Index 452: NO_DATA not found at URL.
# Skipping Index 453: NO_DATA not found at URL.
# Skipping Index 454: NO_DATA not found at URL.
# Skipping Index 455: NO_DATA not found at URL.
# Skipping Index 456: NO_DATA not found at URL.
# Skipping Index 457: NO_DATA not found at URL.
# Skipping Index 458: NO_DATA not found at URL.
# Skipping Index 459: NO_DATA not found at URL.
# Skipping Index 460: NO_DATA not found at URL.
# Skipping Index 461: NO_DATA not found at URL.
# Skipping Index 462: NO_DATA not found at URL.
# Skipping Index 463: NO_DATA not found at URL.
# Skipping Index 464: NO_DATA not found at URL.
# Skipping Index 465: NO_DATA not found at URL.
# Skipping Index 466: NO_DATA not found at URL.
# Skipping Index 467: NO_DATA not found at URL.
# Skipping Index 468: NO_DATA not found at URL.
# Skipping Index 469: NO_DATA not found at URL.
# Skipping Index 470: NO_DATA not found at URL.
# Skipping Index 471: NO_DATA not found at URL.
# Skipping Index 472: NO_DATA not found at URL.
# Skipping Index 473: NO_DATA not found at URL.
# Skipping Index 474: NO_DATA not found at URL.
# Skipping Index 475: NO_DATA not found at URL.
# Skipping Index 476: NO_DATA not found at URL.
# The temperature for Couples Glen at Saturday, March 26, 2016 at 02:00 PM is 66.1.
# The temperature for East Elmhurst at Saturday, February 13, 2016 at 11:00 PM is -12.1.
# The temperature for Daytona Beach at Saturday, April 02, 2016 at 04:00 PM is 78.2.
# The temperature for Latta at Friday, March 25, 2016 at 04:00 PM is 72.3.
# The temperature for Long Island City at Sunday, February 14, 2016 at 05:00 PM is 4.5.
# The temperature for New York at Friday, June 10, 2016 at 03:00 PM is 71.0.
# The temperature for Eagan Park at Thursday, January 14, 2016 at 09:00 PM is 12.3.
# The temperature for Jamestown Court at Monday, June 27, 2016 at 09:00 PM is 83.8.
# Skipping Index 485: Kalorama Triangle not found at URL.
# The temperature for Columbia Heights at Friday, August 05, 2016 at 07:00 PM is 71.7.
# The temperature for Connecticut Avenue at Friday, August 05, 2016 at 05:00 PM is 88.9.
# The temperature for K Street at Tuesday, August 02, 2016 at 09:00 PM is 72.8.
# The temperature for K Street at Wednesday, August 03, 2016 at 02:00 PM is 78.9.
# The temperature for Karachi at Tuesday, December 27, 2016 at 07:00 AM is 64.6.
# The temperature for Karachi at Tuesday, December 27, 2016 at 08:00 AM is 65.9.
# The temperature for Karachi at Tuesday, December 27, 2016 at 12:00 PM is 78.9.
# The temperature for Karachi at Tuesday, December 27, 2016 at 07:00 PM is 75.6.
# The temperature for Karachi at Wednesday, December 28, 2016 at 01:00 PM is 80.7.
# The temperature for Karachi at Wednesday, December 28, 2016 at 06:00 PM is 76.0.
# The temperature for Karachi at Wednesday, December 28, 2016 at 10:00 PM is 72.5.
# The temperature for Karachi at Thursday, December 29, 2016 at 12:00 AM is 70.0.
# The temperature for Karachi at Thursday, December 29, 2016 at 12:00 PM is 79.5.
# The temperature for Karachi at Thursday, December 29, 2016 at 01:00 PM is 80.8.
# The temperature for Karachi at Thursday, December 29, 2016 at 01:00 PM is 80.8.
# The temperature for Karachi at Thursday, December 29, 2016 at 02:00 PM is 80.8.
# The temperature for Karachi at Thursday, December 29, 2016 at 03:00 PM is 79.7.
# The temperature for Karachi at Thursday, December 29, 2016 at 08:00 PM is 75.2.
# The temperature for Karachi at Friday, December 30, 2016 at 10:00 AM is 75.8.
# The temperature for Karachi at Friday, December 30, 2016 at 11:00 AM is 79.0.
# The temperature for Karachi at Friday, December 30, 2016 at 03:00 PM is 83.8.
# The temperature for Karachi at Friday, December 30, 2016 at 04:00 PM is 83.5.
# The temperature for Karachi at Friday, December 30, 2016 at 11:00 PM is 77.4.
# The temperature for Karachi at Saturday, December 31, 2016 at 01:00 AM is 70.8.
# Skipping Index 510: NO_DATA not found at URL.
# Skipping Index 511: NO_DATA not found at URL.
# Skipping Index 512: NO_DATA not found at URL.
# Skipping Index 513: NO_DATA not found at URL.
# Skipping Index 514: NO_DATA not found at URL.
# Skipping Index 515: NO_DATA not found at URL.
# The temperature for Karachi at Friday, September 23, 2016 at 01:00 PM is 90.6.
# The temperature for Karachi at Saturday, October 08, 2016 at 03:00 PM is 93.9.
# The temperature for Colombo at Wednesday, February 17, 2016 at 03:00 PM is 95.4.
# The temperature for Katunayaka at Wednesday, February 17, 2016 at 04:00 PM is 91.3.
# The temperature for Austin at Thursday, March 17, 2016 at 12:00 PM is 76.2.
# The temperature for Kenner at Sunday, June 26, 2016 at 07:00 PM is 94.5.
# The temperature for Kenner at Tuesday, July 12, 2016 at 07:00 PM is 91.3.
# The temperature for Metairie at Thursday, June 16, 2016 at 02:00 PM is 97.4.
# The temperature for Metairie at Monday, June 27, 2016 at 01:00 PM is 105.6.
# The temperature for New Orleans at Thursday, June 16, 2016 at 07:00 PM is 95.4.
# The temperature for New Orleans at Friday, June 17, 2016 at 04:00 PM is 98.7.
# The temperature for New Orleans at Sunday, June 26, 2016 at 05:00 PM is 98.3.
# The temperature for New Orleans at Saturday, July 09, 2016 at 09:00 AM is 94.5.
# The temperature for New Orleans at Sunday, July 10, 2016 at 06:00 PM is 91.7.
# The temperature for New Orleans at Tuesday, July 12, 2016 at 04:00 PM is 93.8.
# Skipping Index 531: Savon Height not found at URL.
# The temperature for Kilarney Woods at Friday, May 27, 2016 at 10:00 PM is 69.1.
# The temperature for Whitebridge at Friday, May 27, 2016 at 08:00 PM is 56.2.
# The temperature for Financial District at Wednesday, June 08, 2016 at 08:00 PM is 47.5.
# The temperature for Jacksonville at Friday, March 25, 2016 at 10:00 PM is 68.7.
# The temperature for Kissimmee at Friday, April 01, 2016 at 01:00 PM is 92.1.
# The temperature for Kissimmee at Friday, April 01, 2016 at 04:00 PM is 88.7.
# The temperature for Kissimmee at Saturday, April 02, 2016 at 08:00 AM is 78.9.
# The temperature for Kissimmee at Saturday, April 02, 2016 at 11:00 AM is 85.3.
# The temperature for Orlando at Sunday, March 27, 2016 at 01:00 AM is 74.3.
# The temperature for Orlando at Sunday, March 27, 2016 at 11:00 PM is 77.4.
# The temperature for Orlando at Monday, March 28, 2016 at 10:00 PM is 75.2.
# The temperature for Orlando at Tuesday, March 29, 2016 at 11:00 PM is 72.3.
# The temperature for Orlando at Wednesday, March 30, 2016 at 10:00 PM is 70.4.
# The temperature for Orlando at Thursday, March 31, 2016 at 02:00 PM is 84.5.
# The temperature for Orlando at Friday, April 01, 2016 at 04:00 PM is 88.9.
# The temperature for Lahore at Friday, August 26, 2016 at 02:00 PM is 102.5.
# The temperature for Lahore at Friday, August 26, 2016 at 03:00 PM is 102.1.
# The temperature for Lahore at Friday, August 26, 2016 at 06:00 PM is 101.2.
# The temperature for Lahore at Friday, August 26, 2016 at 07:00 PM is 100.3.
# The temperature for Lahore at Saturday, August 27, 2016 at 11:00 AM is 86.3.
# The temperature for Lahore at Saturday, August 27, 2016 at 12:00 PM is 89.1.
# The temperature for Lahore at Tuesday, September 27, 2016 at 01:00 PM is 100.4.
# The temperature for Lahore at Friday, October 07, 2016 at 11:00 AM is 97.3.
# The temperature for Lahore at Friday, October 07, 2016 at 03:00 PM is 97.2.
# The temperature for Lahore at Friday, October 07, 2016 at 06:00 PM is 91.8.
# The temperature for Lahore at Friday, October 07, 2016 at 06:00 PM is 91.8.
# The temperature for Lahore at Thursday, December 22, 2016 at 09:00 PM is 56.1.
# The temperature for Lahore at Thursday, December 22, 2016 at 11:00 PM is 52.1.
# The temperature for Lahore at Friday, December 23, 2016 at 09:00 AM is 55.3.
# The temperature for Lahore at Saturday, December 24, 2016 at 10:00 AM is 61.2.
# The temperature for Lahore at Saturday, December 24, 2016 at 12:00 PM is 67.4.
# The temperature for Lahore at Saturday, December 24, 2016 at 01:00 PM is 69.0.
# The temperature for Lahore at Saturday, December 24, 2016 at 05:00 PM is 67.7.
# The temperature for Lahore at Saturday, December 24, 2016 at 07:00 PM is 59.5.
# The temperature for Lahore at Saturday, December 24, 2016 at 10:00 PM is 53.7.
# The temperature for Lahore at Sunday, December 25, 2016 at 12:00 AM is 53.2.
# The temperature for Lahore at Sunday, December 25, 2016 at 07:00 PM is 59.7.
# The temperature for Lahore at Sunday, December 25, 2016 at 09:00 PM is 54.6.
# The temperature for Lahore at Monday, December 26, 2016 at 08:00 AM is 43.9.
# The temperature for Lahore at Monday, December 26, 2016 at 09:00 AM is 50.8.
# The temperature for Lahore at Monday, December 26, 2016 at 10:00 AM is 56.8.
# The temperature for Lahore at Monday, December 26, 2016 at 11:00 AM is 60.5.
# Skipping Index 574: NO_DATA not found at URL.
# Skipping Index 575: NO_DATA not found at URL.
# Skipping Index 576: NO_DATA not found at URL.
# Skipping Index 577: NO_DATA not found at URL.
# Skipping Index 578: NO_DATA not found at URL.
# Skipping Index 579: NO_DATA not found at URL.
# Skipping Index 580: NO_DATA not found at URL.
# Skipping Index 581: NO_DATA not found at URL.
# Skipping Index 582: NO_DATA not found at URL.
# The temperature for Lake Reams at Saturday, March 26, 2016 at 04:00 PM is 87.1.
# The temperature for Lake Reams at Sunday, March 27, 2016 at 12:00 AM is 73.8.
# The temperature for Whitebridge at Tuesday, January 19, 2016 at 09:00 AM is 25.6.
# The temperature for Lower Garden District at Wednesday, June 15, 2016 at 04:00 PM is 96.8.
# The temperature for Cary at Friday, March 25, 2016 at 01:00 PM is 70.1.
# The temperature for Meredith Townes at Thursday, January 28, 2016 at 03:00 PM is 41.3.
# The temperature for Meredith Townes at Monday, March 07, 2016 at 01:00 PM is 55.6.
# The temperature for Arlington Park at Amberly at Monday, August 01, 2016 at 01:00 PM is 92.9.
# The temperature for Hazelwood at Friday, July 22, 2016 at 11:00 AM is 105.0.
# The temperature for Stonewater at Tuesday, July 19, 2016 at 10:00 AM is 95.0.
# The temperature for New York at Sunday, February 14, 2016 at 04:00 PM is 4.7.
# The temperature for CBD at Wednesday, June 15, 2016 at 03:00 PM is 62.5.
# The temperature for Hudson Square at Tuesday, January 12, 2016 at 12:00 PM is 92.5.
# The temperature for Waverly Place at Friday, June 24, 2016 at 11:00 AM is 80.8.
# The temperature for Whitebridge at Thursday, February 04, 2016 at 06:00 PM is 36.2.
# The temperature for Covington at Monday, June 27, 2016 at 11:00 AM is 90.0.
# The temperature for Mandeville at Monday, June 27, 2016 at 11:00 AM is 60.7.
# The temperature for Storyville at Saturday, June 25, 2016 at 07:00 PM is 93.5.
# The temperature for Capitol One at Friday, May 06, 2016 at 05:00 AM is 52.0.
# The temperature for Asheville at Sunday, October 30, 2016 at 03:00 PM is 71.7.
# The temperature for Berkeley at Friday, November 11, 2016 at 09:00 AM is 61.2.
# The temperature for Newark at Tuesday, May 10, 2016 at 09:00 AM is 51.0.
# The temperature for Palo Alto at Friday, November 11, 2016 at 02:00 PM is 72.8.
# The temperature for Fairmont at Wednesday, January 27, 2016 at 12:00 PM is 23.2.
# The temperature for Fayetteville Street at Monday, March 07, 2016 at 12:00 PM is 53.6.
# The temperature for Arabi at Saturday, June 25, 2016 at 10:00 AM is 101.0.
# The temperature for Kenner at Saturday, July 09, 2016 at 09:00 AM is 94.8.
# The temperature for Mandeville at Monday, June 27, 2016 at 12:00 PM is 60.7.
# The temperature for New Orleans at Thursday, June 16, 2016 at 01:00 PM is 96.6.
# The temperature for New Orleans at Friday, July 08, 2016 at 01:00 PM is 97.9.
# The temperature for Briar Meadow at Sunday, March 20, 2016 at 06:00 PM is 52.7.
# The temperature for Downtown at Monday, March 21, 2016 at 04:00 PM is 61.5.
# The temperature for Flatiron District at Monday, January 11, 2016 at 11:00 AM is 21.3.
# The temperature for Hell's Kitchen at Tuesday, January 12, 2016 at 03:00 PM is 30.9.
# The temperature for Midtown at Friday, March 18, 2016 at 07:00 AM is 33.4.
# The temperature for Midtown at Friday, March 18, 2016 at 08:00 AM is 36.7.
# The temperature for Midtown East at Monday, January 11, 2016 at 02:00 PM is 33.8.
# The temperature for Sharpstown at Thursday, March 17, 2016 at 09:00 PM is 47.5.
# The temperature for Sharpstown at Friday, March 18, 2016 at 09:00 PM is 45.1.
# The temperature for Sharpstown at Monday, March 21, 2016 at 08:00 PM is 34.2.
# The temperature for Washington Avenue at Sunday, March 20, 2016 at 11:00 AM is 30.0.
# The temperature for Midtown at Monday, January 11, 2016 at 01:00 PM is 21.6.
# The temperature for Midtown at Sunday, February 14, 2016 at 02:00 PM is 2.4.
# The temperature for Cary at Sunday, January 10, 2016 at 08:00 AM is 51.7.
# The temperature for Cary at Thursday, February 04, 2016 at 08:00 AM is 57.5.
# The temperature for Cary at Sunday, February 07, 2016 at 06:00 PM is 30.1.
# The temperature for Cary at Tuesday, February 09, 2016 at 06:00 PM is 29.1.
# The temperature for Cary at Friday, February 12, 2016 at 02:00 PM is 23.2.
# The temperature for Cary at Saturday, February 13, 2016 at 02:00 PM is 21.4.
# The temperature for Cary at Friday, March 04, 2016 at 07:00 PM is 42.6.
# The temperature for Cary at Saturday, March 05, 2016 at 11:00 AM is 41.5.
# ...
# The temperature for Islamabad at Thursday, October 13, 2016 at 04:00 PM is 84.4.
# The temperature for Islamabad at Monday, December 19, 2016 at 07:00 PM is 52.6.
# The temperature for Islamabad at Tuesday, December 20, 2016 at 06:00 PM is 55.3.
# The temperature for Islamabad at Wednesday, December 21, 2016 at 11:00 AM is 65.4.
# The temperature for Islamabad at Wednesday, December 21, 2016 at 05:00 PM is 61.9.
# The temperature for Karachi at Tuesday, December 27, 2016 at 02:00 PM is 80.0.
# The temperature for Karachi at Wednesday, December 28, 2016 at 08:00 AM is 60.3.
# The temperature for Karachi at Wednesday, December 28, 2016 at 03:00 PM is 79.6.
# The temperature for Karachi at Thursday, December 29, 2016 at 09:00 AM is 71.4.
# The temperature for Karachi at Thursday, December 29, 2016 at 06:00 PM is 77.1.
# The temperature for Karachi at Thursday, December 29, 2016 at 08:00 PM is 75.2.
# The temperature for Karachi at Saturday, December 31, 2016 at 01:00 PM is 78.2.
# The temperature for Karachi at Saturday, September 24, 2016 at 02:00 PM is 89.4.
# The temperature for Karachi at Saturday, October 08, 2016 at 06:00 PM is 89.8.
# The temperature for Katunayaka at Tuesday, February 16, 2016 at 03:00 AM is 85.6.
# The temperature for Lahore at Thursday, August 25, 2016 at 10:00 PM is 93.0.
# The temperature for Lahore at Friday, August 26, 2016 at 03:00 PM is 102.1.
# The temperature for Lahore at Friday, August 26, 2016 at 08:00 PM is 99.6.
# The temperature for Lahore at Saturday, August 27, 2016 at 02:00 PM is 93.8.
# The temperature for Lahore at Tuesday, September 27, 2016 at 07:00 PM is 93.7.
# The temperature for Lahore at Friday, October 07, 2016 at 01:00 PM is 98.7.
# The temperature for Lahore at Friday, December 23, 2016 at 11:00 AM is 67.3.
# The temperature for Lahore at Saturday, December 24, 2016 at 07:00 AM is 44.4.
# The temperature for Lahore at Monday, December 26, 2016 at 01:00 PM is 64.0.
# Skipping Index 943: Noorpur Shahan not found at URL.
# Skipping Index 944: Noorpur Shahan not found at URL.
# The temperature for Nugegoda at Tuesday, February 16, 2016 at 05:00 PM is 90.1.
# The temperature for Oakland at Monday, June 13, 2016 at 08:00 PM is 54.9.
# The temperature for Rawalpindi at Saturday, February 20, 2016 at 04:00 PM is 63.7.
# The temperature for Rawalpindi at Monday, August 15, 2016 at 09:00 AM is 90.6.
# The temperature for Rawalpindi at Friday, August 19, 2016 at 10:00 AM is 95.3.
# The temperature for Rawalpindi at Monday, August 22, 2016 at 10:00 PM is 88.2.
# The temperature for Rawalpindi at Monday, September 19, 2016 at 06:00 AM is 79.7.
# The temperature for Rawalpindi at Thursday, October 06, 2016 at 05:00 PM is 82.4.
# The temperature for Rawalpindi at Wednesday, October 12, 2016 at 07:00 PM is 74.1.
# The temperature for Rawalpindi at Friday, October 14, 2016 at 10:00 AM is 82.0.
# The temperature for Rawalpindi at Monday, December 19, 2016 at 01:00 PM is 63.8.
# The temperature for Rawalpindi at Tuesday, December 20, 2016 at 11:00 AM is 60.6.
# The temperature for Rawalpindi at Wednesday, December 21, 2016 at 08:00 PM is 50.3.
# Skipping Index 958: NO_DATA not found at URL.
# Skipping Index 959: NO_DATA not found at URL.
# Skipping Index 960: NO_DATA not found at URL.
# Skipping Index 961: NO_DATA not found at URL.
# Skipping Index 962: NO_DATA not found at URL.
# Skipping Index 963: NO_DATA not found at URL.
# Skipping Index 964: NO_DATA not found at URL.
# Skipping Index 965: NO_DATA not found at URL.
# Skipping Index 966: NO_DATA not found at URL.
# Skipping Index 967: NO_DATA not found at URL.
# Skipping Index 968: NO_DATA not found at URL.
# Skipping Index 969: NO_DATA not found at URL.
# Skipping Index 970: NO_DATA not found at URL.
# Skipping Index 971: NO_DATA not found at URL.
# Skipping Index 972: NO_DATA not found at URL.
# Skipping Index 973: NO_DATA not found at URL.
# Skipping Index 974: NO_DATA not found at URL.
# Skipping Index 975: NO_DATA not found at URL.
# Skipping Index 976: NO_DATA not found at URL.
# Skipping Index 977: NO_DATA not found at URL.
# Skipping Index 978: NO_DATA not found at URL.
# Skipping Index 979: NO_DATA not found at URL.
# Skipping Index 980: NO_DATA not found at URL.
# Skipping Index 981: NO_DATA not found at URL.
# Skipping Index 982: NO_DATA not found at URL.
# Skipping Index 983: NO_DATA not found at URL.
# Skipping Index 984: NO_DATA not found at URL.
# Skipping Index 985: NO_DATA not found at URL.
# Skipping Index 986: NO_DATA not found at URL.
# Skipping Index 987: NO_DATA not found at URL.
# Skipping Index 988: NO_DATA not found at URL.
# Skipping Index 989: NO_DATA not found at URL.
# Skipping Index 990: NO_DATA not found at URL.
# Skipping Index 991: NO_DATA not found at URL.
# Skipping Index 992: NO_DATA not found at URL.
# Skipping Index 993: NO_DATA not found at URL.
# Skipping Index 994: NO_DATA not found at URL.
# Skipping Index 995: NO_DATA not found at URL.
# Skipping Index 996: NO_DATA not found at URL.
# Skipping Index 997: NO_DATA not found at URL.
# Skipping Index 998: NO_DATA not found at URL.
# Skipping Index 999: NO_DATA not found at URL.
# Skipping Index 1000: NO_DATA not found at URL.
# Skipping Index 1001: NO_DATA not found at URL.
# Skipping Index 1002: NO_DATA not found at URL.
# Skipping Index 1003: NO_DATA not found at URL.
# Skipping Index 1004: NO_DATA not found at URL.
# Skipping Index 1005: NO_DATA not found at URL.
# Skipping Index 1006: NO_DATA not found at URL.
# Skipping Index 1007: NO_DATA not found at URL.
# Skipping Index 1008: NO_DATA not found at URL.
# Skipping Index 1009: NO_DATA not found at URL.
# Skipping Index 1010: NO_DATA not found at URL.
# Skipping Index 1011: NO_DATA not found at URL.
# Skipping Index 1012: NO_DATA not found at URL.
# Skipping Index 1013: NO_DATA not found at URL.
# Skipping Index 1014: NO_DATA not found at URL.
# Skipping Index 1015: NO_DATA not found at URL.
# Skipping Index 1016: NO_DATA not found at URL.
# Skipping Index 1017: NO_DATA not found at URL.
# Skipping Index 1018: NO_DATA not found at URL.
# Skipping Index 1019: NO_DATA not found at URL.
# Skipping Index 1020: NO_DATA not found at URL.
# Skipping Index 1021: NO_DATA not found at URL.
# Skipping Index 1022: NO_DATA not found at URL.
# Skipping Index 1023: NO_DATA not found at URL.
# Skipping Index 1024: NO_DATA not found at URL.
# Skipping Index 1025: NO_DATA not found at URL.
# Skipping Index 1026: NO_DATA not found at URL.
# Skipping Index 1027: NO_DATA not found at URL.
# Skipping Index 1028: NO_DATA not found at URL.
# Skipping Index 1029: NO_DATA not found at URL.
# Skipping Index 1030: NO_DATA not found at URL.
# Skipping Index 1031: NO_DATA not found at URL.
# Skipping Index 1032: NO_DATA not found at URL.
# Skipping Index 1033: NO_DATA not found at URL.
# Skipping Index 1034: NO_DATA not found at URL.
# Skipping Index 1035: NO_DATA not found at URL.
# Skipping Index 1036: NO_DATA not found at URL.
# Skipping Index 1037: NO_DATA not found at URL.
# Skipping Index 1038: NO_DATA not found at URL.
# Skipping Index 1039: NO_DATA not found at URL.
# Skipping Index 1040: NO_DATA not found at URL.
# Skipping Index 1041: NO_DATA not found at URL.
# Skipping Index 1042: NO_DATA not found at URL.
# Skipping Index 1043: NO_DATA not found at URL.
# The temperature for Couples Glen at Monday, March 28, 2016 at 07:00 PM is 58.3.
# The temperature for Cary at Saturday, December 03, 2016 at 06:00 PM is 40.9.
# The temperature for Cary at Thursday, August 11, 2016 at 06:00 PM is 92.7.
# The temperature for Eastgate at Thursday, February 11, 2016 at 05:00 PM is 78.0.
# The temperature for Arlington at Tuesday, August 02, 2016 at 11:00 AM is 97.6.
# The temperature for Midtown at Sunday, March 20, 2016 at 07:00 AM is 20.4.
# The temperature for Whitebridge at Sunday, February 28, 2016 at 05:00 AM is 19.8.
# The temperature for Whitebridge at Tuesday, March 08, 2016 at 02:00 PM is 31.8.
# The temperature for Whitebridge at Saturday, April 30, 2016 at 06:00 PM is 36.3.
# The temperature for Whitebridge at Friday, June 24, 2016 at 10:00 AM is 59.1.
# The temperature for Whitebridge at Tuesday, August 09, 2016 at 02:00 PM is 48.0.
# The temperature for Whitebridge at Tuesday, March 01, 2016 at 06:00 PM is 25.6.
# The temperature for Whitebridge at Saturday, March 05, 2016 at 02:00 PM is 27.1.
# The temperature for Whitebridge at Tuesday, April 05, 2016 at 09:00 PM is 35.4.
# The temperature for Whitebridge at Tuesday, April 19, 2016 at 05:00 PM is 40.2.
# The temperature for Central at Saturday, November 12, 2016 at 01:00 PM is 90.3.
# The temperature for Downtown at Sunday, November 06, 2016 at 07:00 PM is 65.0.
# The temperature for Southside at Sunday, November 13, 2016 at 11:00 AM is 40.6.
# The temperature for Fort Pierce at Wednesday, January 06, 2016 at 02:00 PM is 67.4.
# The temperature for West Palm Beach at Wednesday, January 06, 2016 at 05:00 PM is 70.9.
# The temperature for Convention Center District at Wednesday, March 16, 2016 at 02:00 PM is 70.0.
# The temperature for East Austin at Thursday, March 10, 2016 at 10:00 AM is 58.1.
# The temperature for Hazelwood at Monday, July 18, 2016 at 08:00 PM is 91.1.
# The temperature for Huntington Woods at Friday, June 03, 2016 at 07:00 PM is 76.1.
# The temperature for Huntington Woods at Thursday, October 27, 2016 at 08:00 PM is 37.2.
# The temperature for Weston at Saturday, March 05, 2016 at 12:00 PM is 33.7.
# The temperature for Weston at Sunday, June 05, 2016 at 03:00 PM is 73.1.
# The temperature for Lexington Park at Amberly at Monday, August 01, 2016 at 01:00 PM is 93.0.
# The temperature for Preston at Tuesday, May 17, 2016 at 01:00 PM is 54.3.
# The temperature for Whitebridge at Tuesday, January 26, 2016 at 04:00 PM is 39.7.
# The temperature for Whitebridge at Friday, February 26, 2016 at 09:00 AM is 20.8.
# The temperature for Whitebridge at Friday, February 26, 2016 at 02:00 PM is 30.3.
# The temperature for Whitebridge at Monday, February 29, 2016 at 11:00 AM is 27.3.
# The temperature for Whitebridge at Thursday, March 03, 2016 at 09:00 AM is 29.9.
# The temperature for Whitebridge at Thursday, March 24, 2016 at 07:00 PM is 34.9.
# The temperature for Whitebridge at Sunday, May 01, 2016 at 01:00 PM is 39.8.
# The temperature for Whitebridge at Monday, May 02, 2016 at 02:00 PM is 40.6.
# The temperature for Whitebridge at Wednesday, June 29, 2016 at 11:00 AM is 50.9.
# The temperature for Whitebridge at Tuesday, July 26, 2016 at 03:00 PM is 52.7.
# The temperature for Whitebridge at Friday, July 29, 2016 at 03:00 PM is 54.4.
# The temperature for Whitebridge at Friday, August 12, 2016 at 06:00 PM is 56.9.
# The temperature for Whitebridge at Wednesday, November 02, 2016 at 03:00 PM is 40.4.
# The temperature for Whitebridge at Thursday, November 03, 2016 at 01:00 PM is 39.0.
# The temperature for Burtrose at Wednesday, April 27, 2016 at 02:00 PM is 86.7.
# The temperature for Chessington at Tuesday, July 19, 2016 at 05:00 PM is 84.7.
# The temperature for Edgehill Farms at Saturday, February 06, 2016 at 07:00 PM is 37.3.
# The temperature for Edgehill Farms at Monday, February 08, 2016 at 02:00 PM is 29.1.
# The temperature for Edgehill Farms at Sunday, August 07, 2016 at 05:00 PM is 56.9.
# The temperature for Edgehill Farms at Monday, August 08, 2016 at 05:00 PM is 53.2.
# The temperature for Edgehill Farms at Thursday, August 11, 2016 at 01:00 PM is 58.0.
# The temperature for Edgehill Farms at Tuesday, October 18, 2016 at 08:00 AM is 41.8.
# The temperature for Farmington Woods at Monday, January 18, 2016 at 04:00 PM is 23.9.
# The temperature for Hazelwood at Tuesday, January 26, 2016 at 12:00 PM is 24.0.
# The temperature for Hazelwood at Friday, February 26, 2016 at 05:00 PM is 35.1.
# The temperature for Hazelwood at Monday, February 29, 2016 at 04:00 PM is 56.2.
# The temperature for Hazelwood at Monday, June 06, 2016 at 04:00 PM is 81.1.
# The temperature for Hazelwood at Thursday, November 03, 2016 at 12:00 PM is 69.9.
# The temperature for Heritage Pines at Thursday, February 25, 2016 at 04:00 PM is 27.0.
# The temperature for Kilarney Woods at Saturday, May 28, 2016 at 12:00 AM is 66.6.
# The temperature for Krendle Woods at Friday, November 18, 2016 at 09:00 PM is 54.2.
# The temperature for Lake Wellingborough at Tuesday, January 19, 2016 at 10:00 AM is 14.3.
# The temperature for Lexington Park at Amberly at Tuesday, July 19, 2016 at 11:00 AM is 99.6.
# The temperature for Northwoods at Monday, February 01, 2016 at 12:00 PM is 45.0.
# The temperature for Parkway at Sunday, May 01, 2016 at 10:00 PM is 51.7.
# The temperature for Parkway at Sunday, June 12, 2016 at 09:00 PM is 87.8.
# The temperature for Parkway at Monday, July 25, 2016 at 11:00 AM is 91.8.
# The temperature for Parkway at Tuesday, October 25, 2016 at 10:00 PM is 53.0.
# The temperature for Parkway at Wednesday, October 26, 2016 at 08:00 PM is 62.6.
# The temperature for Preston at Tuesday, February 09, 2016 at 01:00 PM is 31.3.
# The temperature for Preston at Wednesday, February 24, 2016 at 03:00 PM is 33.3.
# The temperature for Preston at Wednesday, March 23, 2016 at 02:00 PM is 39.4.
# The temperature for Preston at Monday, July 18, 2016 at 11:00 AM is 69.0.
# The temperature for Preston at Wednesday, July 20, 2016 at 06:00 PM is 65.4.
# Skipping Index 1117: Savon Height not found at URL.
# Skipping Index 1118: Savon Height not found at URL.
# The temperature for Summerwinds at Monday, July 04, 2016 at 06:00 PM is 92.7.
# The temperature for Tanglewood at Thursday, February 25, 2016 at 06:00 PM is 30.6.
# The temperature for Tanglewood at Saturday, April 23, 2016 at 06:00 PM is 44.6.
# The temperature for Waverly Place at Sunday, February 28, 2016 at 09:00 AM is 31.1.
# The temperature for Waverly Place at Tuesday, March 08, 2016 at 03:00 PM is 54.2.
# The temperature for Waverly Place at Saturday, April 30, 2016 at 10:00 PM is 41.8.
# The temperature for Wayne Ridge at Tuesday, March 01, 2016 at 09:00 PM is 65.6.
# The temperature for Wayne Ridge at Wednesday, April 06, 2016 at 12:00 AM is 62.6.
# The temperature for Wayne Ridge at Tuesday, April 19, 2016 at 07:00 PM is 63.0.
# The temperature for Wayne Ridge at Friday, July 22, 2016 at 06:00 PM is 53.8.
# The temperature for Westpark Place at Friday, February 26, 2016 at 11:00 AM is 37.5.
# The temperature for Westpark Place at Thursday, March 03, 2016 at 11:00 AM is 38.3.
# The temperature for Westpark Place at Thursday, March 24, 2016 at 08:00 PM is 62.1.
# The temperature for Westpark Place at Friday, April 08, 2016 at 01:00 PM is 53.5.
# The temperature for Westpark Place at Sunday, May 01, 2016 at 02:00 PM is 75.8.
# The temperature for Westpark Place at Monday, May 02, 2016 at 03:00 PM is 83.7.
# The temperature for Westpark Place at Tuesday, May 17, 2016 at 02:00 PM is 72.0.
# The temperature for Westpark Place at Tuesday, May 31, 2016 at 05:00 PM is 84.3.
# The temperature for Westpark Place at Saturday, June 11, 2016 at 05:00 PM is 91.9.
# The temperature for Westpark Place at Wednesday, June 29, 2016 at 12:00 PM is 96.2.
# The temperature for Westpark Place at Tuesday, July 26, 2016 at 05:00 PM is 98.5.
# The temperature for Westpark Place at Friday, July 29, 2016 at 05:00 PM is 99.2.
# The temperature for Westpark Place at Sunday, July 31, 2016 at 05:00 PM is 93.8.
# The temperature for Westpark Place at Friday, August 12, 2016 at 06:00 PM is 96.4.
# The temperature for Westpark Place at Wednesday, November 02, 2016 at 03:00 PM is 78.9.
# The temperature for Westpark Place at Thursday, November 03, 2016 at 02:00 PM is 79.8.
# The temperature for Whitebridge at Tuesday, March 08, 2016 at 04:00 PM is 31.8.
# The temperature for Whitebridge at Tuesday, March 22, 2016 at 07:00 PM is 41.0.
# The temperature for Whitebridge at Tuesday, July 05, 2016 at 04:00 PM is 52.3.
# The temperature for Whitebridge at Tuesday, November 01, 2016 at 05:00 PM is 36.3.
# The temperature for Whitebridge at Tuesday, November 01, 2016 at 07:00 PM is 35.2.
# The temperature for Whitebridge at Tuesday, November 01, 2016 at 07:00 PM is 35.2.
# The temperature for Whitebridge at Tuesday, November 01, 2016 at 08:00 PM is 34.5.
# The temperature for Whitebridge at Tuesday, February 02, 2016 at 01:00 PM is 26.2.
# The temperature for Cary at Friday, October 28, 2016 at 03:00 PM is 68.5.

# %%
df.head(500)
# Out:
#              START_DATE            END_DATE  CATEGORY        START     STOP  \
# 0   2016-11-05 19:20:00 2016-11-05 19:28:00  Business        Agnew    Agnew
# 1   2016-11-04 22:12:00 2016-11-04 22:25:00  Business         Cory    Agnew
# 2   2016-11-05 17:29:00 2016-11-05 17:40:00  Business  Renaissance    Agnew
# 3   2016-11-06 16:05:00 2016-11-06 16:22:00  Business  Renaissance    Agnew
# 4   2016-03-17 17:20:00 2016-03-17 18:02:00  Business      Midtown    Alief
# ..                  ...                 ...       ...          ...      ...
# 495 2016-12-28 18:33:00 2016-12-28 18:56:00  Business      Karachi  Karachi
# 496 2016-12-28 22:44:00 2016-12-28 23:18:00  Business      Karachi  Karachi
# 497 2016-12-29 00:49:00 2016-12-29 01:06:00  Business      Karachi  Karachi
# 498 2016-12-29 12:25:00 2016-12-29 12:33:00  Business      Karachi  Karachi
# 499 2016-12-29 13:17:00 2016-12-29 13:24:00  Business      Karachi  Karachi
#
#      MILES          PURPOSE  TEMPERATURE  IS_DAY  RAIN  SNOWFALL  SHOWERS  \
# 0      2.2          NO_DATA         49.3     0.0   0.0       0.0      0.0
# 1      3.9          NO_DATA         41.6     0.0   0.0       0.0      0.0
# 2      2.8          NO_DATA         52.5     0.0   0.0       0.0      0.0
# 3      2.8          Meeting         43.9     1.0   0.0       0.0      0.0
# 4     15.5   Meal/Entertain         50.9     1.0   0.0       0.0      0.0
# ..     ...              ...          ...     ...   ...       ...      ...
# 495    3.8  Errand/Supplies         76.0     0.0   0.0       0.0      0.0
# 496    5.1  Errand/Supplies         72.5     0.0   0.0       0.0      0.0
# 497    3.8  Errand/Supplies         70.0     0.0   0.0       0.0      0.0
# 498    1.4  Errand/Supplies         79.5     1.0   0.0       0.0      0.0
# 499    1.1  Errand/Supplies         80.8     1.0   0.0       0.0      0.0
#
#      WEATHER_CODE  WIND_SPEED_10M  WIND_GUSTS_10M
# 0             1.0             4.0             5.0
# 1             0.0             6.2            13.3
# 2             1.0             7.0            14.8
# 3             0.0            16.3            34.6
# 4             3.0             6.8            28.1
# ..            ...             ...             ...
# 495           0.0            10.2            19.1
# 496           0.0             8.1            11.5
# 497           1.0             8.1            11.2
# 498           0.0             9.4            20.5
# 499           0.0            11.5            23.8
#
# [500 rows x 15 columns]

# %% [markdown]
# 10. Prep the DataFrame so that it would be ready for modeling (don't worry, we won't start modeling just yet!):
#
# a) keep only numeric columns (in a copy)
#
# b) fill in Na values with the group-wise mean for each START location if applicable
#
# c) create these interaction features:
#   - Temperature x Wind Speed (Low temp AND high winds = awful combo, high temp AND high winds = good combo)
#   - Overall Weather Stress (Hint: summation)

# %%
weather_cols = ['TEMPERATURE', 'RAIN', 'WIND_SPEED_10M', 'SNOWFALL', 'SHOWERS', 'WEATHER_CODE', 'WIND_GUSTS_10M']

# 1. Impute missing values directly in the original DataFrame
for col in weather_cols:
    if col in df.columns:
        # Calculate the mean grouped by 'START' and fill NaNs in-place
        group_mean = df.groupby('START')[col].transform('mean')
        df[col] = df[col].fillna(group_mean)

# 2. Create new features directly in 'df'
df['TEMP_WIND'] = df['TEMPERATURE'] * df['WIND_SPEED_10M']

# 3. Calculate Stress
existing_weather_cols = [c for c in weather_cols if c in df.columns]
df['WEATHER_STRESS'] = df[existing_weather_cols].sum(axis=1)

# %%
df.to_csv('UberDataset Updated.csv')
