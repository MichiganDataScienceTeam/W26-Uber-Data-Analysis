# %% [markdown]
# <a href="https://colab.research.google.com/github/MichiganDataScienceTeam/W26-Uber-Data-Analysis/blob/main/Optional__Quick_Numpy_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('UberDataset Current.csv')

# %% [markdown]
# 1. Create a NumPy array from MILES column and print out its shape, dimensions, and total elements
# 2. Using a NumPy array from DURATION_MIN, print out first 10 values, last 5 values, and the reversed array
# 3. From the MILES array, print values at indices: 0, 10, 15, 50
